# %% [markdown]
# #  Evaluations - Inject ACC 13

# %%
import pandas as pd
import numpy as np
import  matplotlib.pyplot as plt
import re
from omnetpp.scave import results, chart, utils
# %matplotlib inline

# %%
config_vec = "InjectACC_13-*.vec"
config_sca = "InjectACC_13-*.sca"

pre = "InjectACC_13_" # prefix for saved files

read_data_from_results = True

# %% [markdown]
# ## Max Latencies

# %% [markdown]
# ### Function definitions

# %%
def get_device(module):
    return module.split(".")[1]

def get_streamId(module, df):
    # assumning that streamIds are deterministic
    attrname = "*." + module.split(".")[1] + "." + module.split(".")[2] + ".display-name"
    attrval = df.loc[df['attrname'] == attrname,'attrvalue']
    try:
        return attrval.to_list()[0].split(" ")[0]
    except:
        return " "

def streamencodings(df):
    df_notna = df[df['attrname'].notna()]
    all_encodings = df_notna.loc[df_notna['attrname'].str.contains(".bridging.streamCoder.encoder.mapping")]
    # build a single json file based on streamname as key
    encodings = dict()
    for idx, row in all_encodings.iterrows():
        dev = row['attrname']
        encoding_str = row['attrvalue']
        encoding = re.findall(r'\{([^}]*)\}', encoding_str)
        for item in encoding:
            enc = item.split(",")  
            for e in enc:
                if "stream" in e:
                    stream = re.findall('"([^"]*)"', e)[0]
                elif "pcp" in e:
                    pcp = re.findall(r'\d+', e)[0]
                elif "vlan" in e:
                    vlan = re.findall(r'\d+', e)[0]
            # add infos to stream encoding
            if stream in encodings.keys():
                if pcp not in encodings[stream]['pcp']:
                    encodings[stream]['pcp'].append(pcp)
                if vlan not in encodings[stream]['vlan']:
                    encodings[stream]['vlan'].append(vlan)
                if dev not in encodings[stream]['dev']:
                    encodings[stream]['dev'].append(dev)
            else:
                encodings[stream] = {'pcp' : [pcp],
                                    'vlan' : [vlan],
                                    'dev' : [dev]}
    return encodings
        
def set_streamId(name): # streamnames are only sometimes deterministic, these are the special cases
    if "_" in name: # CAN
        return "SControl"
    if name == "SReset": # a single stream that is not formatted the same
        return "SControl"
    if name == " ": # Tcp-Stream
        return "SEtsiCamOut"
    
    return name

def get_pcp(streamname, device , df):
    if "zonalController" in device:
        attrname = "*.zonalController*.bridging.streamCoder.decoder.mapping"
    else:
        attrname = "*." + device + ".bridging.streamCoder.decoder.mapping"
    
    try:
        decoding_str = df.loc[df['attrname']==attrname, 'attrvalue'].to_list()[0]
        decoding = re.findall(r'\{([^}]*)\}', decoding_str)
        # get pcp for the stream from the table
        for item in decoding:
            if (streamname + "\"") in item:
                return item.split(",")[1][-1:]
    except:
        return " "

def get_pcp_from_encodings(streamname, encodings):
    try:
        return encodings[streamname]['pcp'][0]
    except:
        return " "
        

def max_delay(vals):
    try:
        return vals.max()
    except Exception as e:
        print(e)
        return "ERROR"


def extract_e2edelay(df):
    res = df[['runID','module', 'vectime', 'vecvalue']].dropna()
    res['device'] = res.apply(lambda row: get_device(row['module']), axis=1)
    res['streamname'] = res.apply(lambda row: get_streamId(row['module'], df), axis=1)
    res['streamname-Control'] = res.apply(lambda row: set_streamId(row['streamname']), axis=1)
    encodings  = streamencodings(df)
    res['pcp'] = res.apply(lambda row: get_pcp_from_encodings(row['streamname-Control'], encodings), axis=1)
    res['max e2e delay'] = res.apply(lambda row: max_delay(row['vecvalue']), axis=1)
    
    return res

# %% [markdown]
# ### Evaluate latencies and jitter

# %%
# read results
if read_data_from_results:
    res = results.read_result_files(filenames = config_vec,
                                filter_expression = "name =~ meanBitLifeTimePerPacket:vector")
    latencies = extract_e2edelay(res)
    latencies.to_pickle(pre+"latencies_data")
else:
    latencies = pd.read_pickle(pre+"latencies_data")

# %%
latency_jitter_by_priority = []
for prio, group in latencies.groupby('pcp'):
    sorted = group.sort_values('max e2e delay', ascending = False)
    
    max_latency = group['max e2e delay'].max()
    min_latency = group['max e2e delay'].min()
    jitter = max_latency - min_latency

    max_stream = group.loc[group['max e2e delay'] == max_latency, 'module'].to_list()

    latency_jitter_by_priority.append({"pcp": prio,
                                       "max latency [s]": max_latency,
                                       "min latency [s]": min_latency,
                                       "jitter [s]": jitter,
                                       "stream with max latency": max_stream
                                      })

df_latency_prio = pd.DataFrame(latency_jitter_by_priority)

df_latency_prio.to_csv(pre+"latency_by_prio.csv", index=False)
df_latency_prio
# Out:
#   pcp  max latency [s]  min latency [s]  jitter [s]  \
# 0   2         0.000259         0.000034    0.000225
# 1   4         0.000290         0.000005    0.000285
# 2   5         0.000159         0.000059    0.000100
# 3   6         0.000999         0.000007    0.000991
#
#                              stream with max latency
# 0  [Car.connectivityGateway.app[0].connection[0]....
# 1        [Car.zonalControllerRearRight.app[91].sink]
# 2                             [Car.adas.app[2].sink]
# 3          [Car.zonalControllerRearLeft.app[2].sink]

# %% [markdown]
# ### Latencies Prio 6, per stream

# %%
l_p6  = latencies.loc[latencies['pcp'] == "6"].copy()

# %%
l_p6['min e2e delay'] = l_p6.apply(lambda row: row['vecvalue'].min(), axis=1)
l_p6['jitter'] = l_p6.apply(lambda row: row['max e2e delay'] - row['min e2e delay'], axis=1)

# %%
l_p6_streams = l_p6[['module','device', 'streamname', 'max e2e delay', 'min e2e delay', 'jitter']].sort_values('max e2e delay', ascending=False)
l_p6_streams.rename(columns= {'max e2e delay': 'max e2e delay [s]', 'min e2e delay': 'min e2e delay [s]', 'jitter': 'jitter [s]'}, inplace=True)
l_p6_streams.to_csv(pre+"latencies_prio6.csv")

# %%
l_p6_streams
# Out:
#                                          module                     device  \
# 3519    Car.zonalControllerRearLeft.app[2].sink    zonalControllerRearLeft
# 3477    Car.zonalControllerRearLeft.app[1].sink    zonalControllerRearLeft
# 3435    Car.zonalControllerRearLeft.app[0].sink    zonalControllerRearLeft
# 3540    Car.zonalControllerRearLeft.app[5].sink    zonalControllerRearLeft
# 3498    Car.zonalControllerRearLeft.app[4].sink    zonalControllerRearLeft
# 3533  Car.zonalControllerFrontRight.app[5].sink  zonalControllerFrontRight
# 3491  Car.zonalControllerFrontRight.app[4].sink  zonalControllerFrontRight
# 3456    Car.zonalControllerRearLeft.app[3].sink    zonalControllerRearLeft
# 3449  Car.zonalControllerFrontRight.app[3].sink  zonalControllerFrontRight
# 3561   Car.zonalControllerRearRight.app[2].sink   zonalControllerRearRight
# 3554   Car.zonalControllerRearRight.app[1].sink   zonalControllerRearRight
# 3512  Car.zonalControllerFrontRight.app[2].sink  zonalControllerFrontRight
# 3547   Car.zonalControllerFrontLeft.app[5].sink   zonalControllerFrontLeft
# 3505   Car.zonalControllerFrontLeft.app[4].sink   zonalControllerFrontLeft
# 3526   Car.zonalControllerRearRight.app[0].sink   zonalControllerRearRight
# 3470  Car.zonalControllerFrontRight.app[1].sink  zonalControllerFrontRight
# 3463   Car.zonalControllerFrontLeft.app[3].sink   zonalControllerFrontLeft
# 3428  Car.zonalControllerFrontRight.app[0].sink  zonalControllerFrontRight
# 3484   Car.zonalControllerRearRight.app[5].sink   zonalControllerRearRight
# 3442   Car.zonalControllerRearRight.app[4].sink   zonalControllerRearRight
# 3421   Car.zonalControllerRearRight.app[3].sink   zonalControllerRearRight
#
#            streamname  max e2e delay [s]  min e2e delay [s]  jitter [s]
# 3519     SManualSteer           0.000999           0.000005    0.000994
# 3477     SManualBrake           0.000998           0.000004    0.000994
# 3435  SManualThrottle           0.000997           0.000003    0.000994
# 3540       SAutoSteer           0.000027           0.000007    0.000021
# 3498       SAutoBrake           0.000025           0.000006    0.000020
# 3533       SAutoSteer           0.000025           0.000008    0.000017
# 3491       SAutoBrake           0.000024           0.000006    0.000018
# 3456    SAutoThrottle           0.000023           0.000004    0.000019
# 3449    SAutoThrottle           0.000023           0.000004    0.000019
# 3561     SManualSteer           0.000022           0.000005    0.000016
# 3554     SManualBrake           0.000020           0.000005    0.000015
# 3512     SManualSteer           0.000020           0.000007    0.000013
# 3547       SAutoSteer           0.000019           0.000007    0.000012
# 3505       SAutoBrake           0.000018           0.000006    0.000012
# 3526  SManualThrottle           0.000018           0.000004    0.000014
# 3470     SManualBrake           0.000018           0.000005    0.000013
# 3463    SAutoThrottle           0.000017           0.000005    0.000012
# 3428  SManualThrottle           0.000016           0.000003    0.000013
# 3484       SAutoSteer           0.000011           0.000006    0.000005
# 3442       SAutoBrake           0.000009           0.000005    0.000005
# 3421    SAutoThrottle           0.000007           0.000003    0.000005

# %% [markdown]
# ### Latencies Prio 5, per stream

# %%
l_p5  = latencies.loc[latencies['pcp'] == "5"].copy()

l_p5['min e2e delay'] = l_p5.apply(lambda row: row['vecvalue'].min(), axis=1)
l_p5['jitter'] = l_p5.apply(lambda row: row['max e2e delay'] - row['min e2e delay'], axis=1)

l_p5_streams = l_p5[['module','device', 'streamname', 'max e2e delay', 'min e2e delay', 'jitter']].sort_values('max e2e delay', ascending=False)
l_p5_streams.rename(columns= {'max e2e delay': 'max e2e delay [s]', 'min e2e delay': 'min e2e delay [s]', 'jitter': 'jitter [s]'}, inplace=True)
l_p5_streams.to_csv(pre+"latencies_prio5.csv")

l_p5_streams
# Out:
#                     module device        streamname  max e2e delay [s]  \
# 3414  Car.adas.app[2].sink   adas   SLidarFrontLeft           0.000159
# 3407  Car.adas.app[4].sink   adas    SLidarRearLeft           0.000131
# 3400  Car.adas.app[3].sink   adas  SLidarFrontRight           0.000130
# 3386  Car.adas.app[1].sink   adas        SVideoRear           0.000123
# 3379  Car.adas.app[0].sink   adas       SVideoFront           0.000117
# 3393  Car.adas.app[5].sink   adas   SLidarRearRight           0.000059
#
#       min e2e delay [s]  jitter [s]
# 3414           0.000068    0.000091
# 3407           0.000046    0.000085
# 3400           0.000042    0.000088
# 3386           0.000034    0.000089
# 3379           0.000034    0.000082
# 3393           0.000029    0.000029

# %% [markdown]
# ### Latencies Prio 4, per stream

# %%
l_p4  = latencies.loc[latencies['pcp'] == "4"].copy()

l_p4['min e2e delay'] = l_p4.apply(lambda row: row['vecvalue'].min(), axis=1)
l_p4['jitter'] = l_p4.apply(lambda row: row['max e2e delay'] - row['min e2e delay'], axis=1)

l_p4_streams = l_p4[['module','device', 'streamname', 'max e2e delay', 'min e2e delay', 'jitter']].sort_values('max e2e delay', ascending=False)
l_p4_streams.rename(columns= {'max e2e delay': 'max e2e delay [s]', 'min e2e delay': 'min e2e delay [s]', 'jitter': 'jitter [s]'}, inplace=True)
l_p4_streams.to_csv(pre+"latencies_prio4.csv")

l_p4_streams
# Out:
#                                           module                    device  \
# 3673   Car.zonalControllerRearRight.app[91].sink  zonalControllerRearRight
# 3645   Car.zonalControllerRearRight.app[89].sink  zonalControllerRearRight
# 3904  Car.zonalControllerRearRight.app[112].sink  zonalControllerRearRight
# 3897   Car.zonalControllerRearRight.app[87].sink  zonalControllerRearRight
# 3890   Car.zonalControllerRearRight.app[86].sink  zonalControllerRearRight
# ...                                          ...                       ...
# 6339               Car.infotainment.app[45].sink              infotainment
# 6332               Car.infotainment.app[35].sink              infotainment
# 6325               Car.infotainment.app[34].sink              infotainment
# 6318               Car.infotainment.app[22].sink              infotainment
# 5632  Car.zonalControllerFrontLeft.app[122].sink  zonalControllerFrontLeft
#
#          streamname  max e2e delay [s]  min e2e delay [s]  jitter [s]
# 3673     SAirbag_03           0.000290           0.000006    0.000284
# 3645     SAirbag_01           0.000289           0.000002    0.000287
# 3904   SGetriebe_06           0.000288           0.000007    0.000281
# 3897        SACC_10           0.000277           0.000007    0.000271
# 3890        SACC_07           0.000277           0.000006    0.000271
# ...             ...                ...                ...         ...
# 6339  SRear_View_01           0.000026           0.000007    0.000019
# 6332      SKombi_03           0.000021           0.000006    0.000015
# 6325      SKombi_02           0.000020           0.000005    0.000015
# 6318  SEinheiten_01           0.000012           0.000005    0.000008
# 5632   SMainUnit_01           0.000005           0.000001    0.000004
#
# [441 rows x 6 columns]

# %% [markdown]
# ### Evaluate if apps receive data

# %%
def get_appno(module):
    num = re.findall(r'\[.*?\]', module)[0]
    nums = re.findall(r'\d+', num)
    if ".." in num:
        r_nums = []
        for i in range (int(nums[0]), int(nums[1])+1):
            r_nums.append(i)
        return r_nums
    else:
        return nums

# %%
# find all configured sinks
df_sinkapps = res.loc[res['attrvalue'].isin(["UdpSinkApp", "TcpClientApp", "TcpServerApp"]), ['attrname', 'attrvalue']]

configured_sinks = []
for idx, row in df_sinkapps.iterrows():
    if ".." in row['attrname']: # config for multiple apps
        nums = get_appno(row['attrname'])
        for n in nums:
            sink = get_device(row['attrname']) + ".app[" + str(n) + "]"
            configured_sinks.append(sink)
    else:
        sink = get_device(row['attrname']) + ".app[" + re.findall(r'\d+', row['attrname'])[0] + "]"
        configured_sinks.append(sink)

# %%
# find all sinks that received at least one packet that is counted towards latency-results
sinks_receiving_data = latencies['module'].to_list()

# and bring them in same format as configured_strings
sinks_receiving_data_formatted = []
for sink in sinks_receiving_data:
    formatted = sink.split(".")[1] + "." + sink.split(".")[2]
    sinks_receiving_data_formatted.append(formatted)

# %%
# compare the lists

# only configured
diff_conf = []
for s in configured_sinks:
    if s not in sinks_receiving_data_formatted:
        diff_conf.append(s)

diff_conf

# all of these apps do have a 'dropped data rate', if you check them by hand, is this wanted?
# Out:
# []

# %%
# only in results
diff_res = []
for s in sinks_receiving_data_formatted:
    if s not in configured_sinks:
        diff_res.append(s)

diff_res
# Out:
# []

# %% [markdown]
# ## Queueing

# %%
### Function definitions
def get_devicePort(module):
    split = module.split(".")
    return split[1] + "." + split[2]

def get_queueNo(module):
    split = module.split(".")
    if len(split) < 6:
        return "all"
    else:
        return split[5]


def extract_maxq(df):
    res = df[['runID', 'module', 'value']].dropna()
    res.sort_values(by='value', ascending=False, inplace=True)
#res_maxq['device'] = res_maxq.apply(lambda row: get_device(row['module']), axis=1)
    res['device+port'] = res.apply(lambda row: get_devicePort(row['module']), axis=1)
    res['queue'] = res.apply(lambda row: get_queueNo(row['module']), axis=1)
    res = res[['runID','device+port', 'queue', 'value']]
    return res

# %% [markdown]
# ### Max queuelengths

# %%
# read results
if read_data_from_results:
    res_q = results.read_result_files(filenames = config_sca,
                                filter_expression = "module =~ *.eth[*].macLayer.queue* AND name =~ queueLength:max")
    max_q = extract_maxq(res_q)
    max_q.to_pickle(pre+"queues_data")
else:
    max_q = pd.read_pickle(pre+"queues_data")

# %%
# queues by priority

qs = []
for q, group in max_q.groupby('queue'):
    max = group['value'].max()
    port = group.loc[group['value'] == max]
    ports = port['device+port'].to_list()
    if q == "all":
       qs.append({"prio": "all",
                "max": max,
                 "port": ports}) 
    else:
        prio = re.findall(r'\d+', q)[0]
        qs.append({"prio": prio,
                   "max": max,
                   "port": ports})

df_qs = pd.DataFrame(qs)

df_qs
# Out:
#   prio    max                                               port
# 0  all  185.0                  [zonalControllerRearRight.eth[0]]
# 1    0  131.0                  [zonalControllerFrontLeft.eth[0]]
# 2    2    2.0  [switchFrontRight.eth[1], switchFrontLeft.eth[0]]
# 3    4   79.0                  [zonalControllerRearRight.eth[0]]
# 4    5    7.0                           [switchRearRight.eth[2]]
# 5    6   14.0                          [switchFrontRight.eth[4]]
# 6    7    4.0  [switchRearLeft.eth[4], switchRearRight.eth[2]...

# %% [markdown]
# ### Queues over time

# %%
def extract_data_qlen(df):
    res = df[['runID','module', 'vectime', 'vecvalue']].dropna()
    res['device+port'] = res.apply(lambda row: get_devicePort(row['module']), axis=1)
    res['queue'] = res.apply(lambda row: get_queueNo(row['module']), axis=1)
    res['max length'] = res.apply(lambda row: row['vecvalue'].max(), axis=1)
    return res

def set_curmax(vec):
    max = 0
    res = []
    for v in vec:
        if v > max:
            max = v
            res.append(v)
        else:
            res.append(max)
    return res

def get_maxtime(time, vec, max):
    m_idx = [i for i, v in enumerate(vec) if v == max]
    return time[m_idx]

# %%
# read results
if read_data_from_results:
    res_qv = results.read_result_files(filenames = config_vec,
                                filter_expression = "module =~ *macLayer.queue* AND name =~ queueLength:vector")
    qvs = extract_data_qlen(res_qv)
    qvs.to_pickle(pre+"queues_vec_data")
else:
    qvs = pd.read_pickle(pre+"queues_vec_data")

# %% [markdown]
# #### classify behaviour of streams (somehow)...

# %%
qvs['current max'] = qvs.apply(lambda row: set_curmax(row['vecvalue']), axis=1)
qvs['times of max'] = qvs.apply(lambda row: get_maxtime(row['vectime'], row['vecvalue'], row['max length']), axis=1)
qvs['latest time of max'] = qvs.apply(lambda row: row['times of max'].max(), axis=1)
qvs['number of max'] = qvs.apply(lambda row: len(row['times of max']), axis=1)

# %%
# Streams that reach their max in the last second (but max reach it before then too)
qvs_lastsec = qvs[['device+port', 'queue', 'max length']].loc[qvs['latest time of max'] > 9.0].sort_values('max length', ascending=False)
qvs_lastsec.loc[qvs_lastsec['queue'] != "all"]
# Out:
#                           device+port     queue  max length
# 3870           switchRearRight.eth[1]  queue[4]        31.0
# 3978            switchRearLeft.eth[4]  queue[4]        18.0
# 4017          switchFrontRight.eth[4]  queue[6]        14.0
# 4033            switchRearLeft.eth[4]  queue[6]        13.0
# 4001           switchFrontLeft.eth[1]  queue[4]        12.0
# 3955           switchRearRight.eth[3]  queue[4]        12.0
# 3932           switchRearRight.eth[3]  queue[6]         9.0
# 3908           switchFrontLeft.eth[0]  queue[6]         9.0
# 4057           switchFrontLeft.eth[4]  queue[6]         7.0
# 4351           switchRearRight.eth[2]  queue[5]         7.0
# 3947           switchRearRight.eth[0]  queue[6]         6.0
# 3924           switchRearRight.eth[1]  queue[6]         6.0
# 3993            switchRearLeft.eth[0]  queue[4]         5.0
# 4327            switchRearLeft.eth[0]  queue[5]         5.0
# 4303          switchFrontRight.eth[1]  queue[5]         5.0
# 4049            switchRearLeft.eth[1]  queue[6]         4.0
# 4135           switchRearRight.eth[3]  queue[7]         4.0
# 4119          switchFrontRight.eth[4]  queue[7]         4.0
# 4065           switchFrontLeft.eth[5]  queue[4]         4.0
# 4025            switchRearLeft.eth[0]  queue[6]         4.0
# 4343           switchFrontLeft.eth[1]  queue[5]         3.0
# 4009          switchFrontRight.eth[1]  queue[6]         3.0
# 3916           switchFrontLeft.eth[1]  queue[6]         3.0
# 4335           switchFrontLeft.eth[0]  queue[5]         3.0
# 4041          switchFrontRight.eth[0]  queue[6]         3.0
# 4173            switchRearLeft.eth[3]  queue[7]         3.0
# 3719  zonalControllerFrontLeft.eth[0]  queue[6]         3.0
# 4271           switchRearRight.eth[0]  queue[7]         2.0
# 4256           switchFrontLeft.eth[3]  queue[7]         2.0
# 4233           switchFrontLeft.eth[5]  queue[7]         2.0
# 4096               masterClock.eth[0]  queue[0]         2.0
# 4218            switchRearLeft.eth[2]  queue[7]         2.0
# 3379           switchFrontLeft.eth[1]  queue[7]         2.0
# 3394           switchFrontLeft.eth[0]  queue[7]         2.0
# 3619                cameraRear.eth[0]  queue[7]         2.0
# 3409          switchFrontRight.eth[0]  queue[7]         2.0
# 3589            lidarRearRight.eth[0]  queue[7]         2.0
# 3574             lidarRearLeft.eth[0]  queue[7]         2.0
# 3544            lidarFrontLeft.eth[0]  queue[7]         2.0
# 3454            switchRearLeft.eth[1]  queue[7]         2.0
# 4080           switchRearRight.eth[1]  queue[2]         1.0
# 3469           switchRearRight.eth[5]  queue[7]         1.0
# 4367            switchRearLeft.eth[1]  queue[2]         1.0
# 3424          switchFrontRight.eth[1]  queue[7]         1.0
# 3439            switchRearLeft.eth[0]  queue[7]         1.0
# 3514   zonalControllerRearLeft.eth[0]  queue[7]         1.0
# 3529  zonalControllerRearRight.eth[0]  queue[7]         1.0
# 3604               cameraFront.eth[0]  queue[7]         1.0
# 3634              infotainment.eth[0]  queue[7]         1.0
# 3664       connectivityGateway.eth[0]  queue[7]         1.0
# 4447           switchRearRight.eth[2]  queue[2]         1.0
# 4399            switchRearLeft.eth[4]  queue[0]         0.0
# 4415           switchFrontLeft.eth[3]  queue[2]         0.0

# %%
# streams that reach max less than 5 times during runtime
qvs_fewmax =qvs[['device+port', 'queue', 'max length', 'number of max', 'times of max']].loc[qvs['number of max'] < 5].sort_values('max length', ascending=False)
qvs_fewmax.loc[qvs_fewmax['queue'] != "all"]
# Out:
#                            device+port     queue  max length  number of max  \
# 3679   zonalControllerFrontLeft.eth[0]  queue[0]       131.0              1
# 3687  zonalControllerFrontRight.eth[0]  queue[0]       120.0              1
# 3703   zonalControllerRearRight.eth[0]  queue[0]       105.0              1
# 3751   zonalControllerRearRight.eth[0]  queue[4]        79.0              1
# 3839           switchFrontRight.eth[1]  queue[4]        78.0              2
# 3735  zonalControllerFrontRight.eth[0]  queue[4]        62.0              1
# 3885            switchFrontLeft.eth[0]  queue[4]        56.0              1
# 4383           switchFrontRight.eth[1]  queue[0]        53.0              1
# 3893            switchFrontLeft.eth[4]  queue[4]        52.0              4
# 3695    zonalControllerRearLeft.eth[0]  queue[0]        46.0              1
# 3727   zonalControllerFrontLeft.eth[0]  queue[4]        43.0              1
# 3711               infotainment.eth[0]  queue[0]        39.0              1
# 4295            switchFrontLeft.eth[4]  queue[0]        30.0              1
# 4088             switchRearLeft.eth[1]  queue[0]        19.0              1
# 4287            switchFrontLeft.eth[0]  queue[0]        18.0              1
# 4017           switchFrontRight.eth[4]  queue[6]        14.0              2
# 3807               infotainment.eth[0]  queue[4]        14.0              1
# 3908            switchFrontLeft.eth[0]  queue[6]         9.0              2
# 4359           switchFrontRight.eth[4]  queue[0]         9.0              1
# 3743    zonalControllerRearLeft.eth[0]  queue[4]         7.0              1
# 4311           switchFrontRight.eth[0]  queue[5]         6.0              1
# 4319             switchRearLeft.eth[1]  queue[5]         6.0              4
# 4375            switchFrontLeft.eth[5]  queue[0]         5.0              2
# 4391            switchRearRight.eth[1]  queue[0]         5.0              1
# 4065            switchFrontLeft.eth[5]  queue[4]         4.0              3
# 4158           switchFrontRight.eth[3]  queue[7]         3.0              1
# 4173             switchRearLeft.eth[3]  queue[7]         3.0              3
# 4143            switchFrontLeft.eth[2]  queue[7]         3.0              1
# 3815                       adas.eth[0]  queue[6]         3.0              1
# 3559            lidarFrontRight.eth[0]  queue[7]         2.0              3
# 4188            switchRearRight.eth[4]  queue[7]         2.0              1
# 4203           switchFrontRight.eth[2]  queue[7]         2.0              4
# 3544             lidarFrontLeft.eth[0]  queue[7]         2.0              3
# 3499  zonalControllerFrontRight.eth[0]  queue[7]         2.0              1
# 3484   zonalControllerFrontLeft.eth[0]  queue[7]         2.0              4
# 3574              lidarRearLeft.eth[0]  queue[7]         2.0              4
# 4439           switchFrontRight.eth[1]  queue[2]         2.0              1
# 3783             lidarRearRight.eth[0]  queue[5]         2.0              1
# 3589             lidarRearRight.eth[0]  queue[7]         2.0              4
# 3619                 cameraRear.eth[0]  queue[7]         2.0              3
# 3649                       adas.eth[0]  queue[7]         2.0              3
# 3759             lidarFrontLeft.eth[0]  queue[5]         2.0              1
# 3767            lidarFrontRight.eth[0]  queue[5]         2.0              1
# 4431            switchFrontLeft.eth[0]  queue[2]         2.0              1
# 3775              lidarRearLeft.eth[0]  queue[5]         2.0              1
# 4423        connectivityGateway.eth[0]  queue[2]         1.0              1
# 3799                 cameraRear.eth[0]  queue[5]         1.0              1
# 4407            switchFrontLeft.eth[1]  queue[0]         1.0              4
# 3823                       adas.eth[0]  queue[2]         1.0              2
# 3791                cameraFront.eth[0]  queue[5]         1.0              1
# 4455            switchRearRight.eth[3]  queue[0]         1.0              2
#
#                                            times of max
# 3679                                              [0.0]
# 3687                                              [0.0]
# 3703                                              [0.0]
# 3751                                              [0.0]
# 3839                   [4.000041863486, 4.000042535486]
# 3735                                              [0.0]
# 3885                                      [3.32665e-05]
# 4383                                      [0.000129682]
# 3893  [4.000023663475, 4.000024335475, 4.00002500747...
# 3695                                              [0.0]
# 3727                                              [0.0]
# 3711                                              [0.0]
# 4295                                      [0.000104298]
# 4088                                      [3.50425e-05]
# 4287                                      [9.64345e-05]
# 4017                 [11.625898197923, 11.750896979883]
# 3807                                              [0.0]
# 3908                 [10.375909607627, 10.625907166985]
# 4359                                      [0.000107522]
# 3743                                              [0.0]
# 4311                                   [5.635026191876]
# 4319  [0.0316657465, 6.496454502094, 6.49675232097, ...
# 4375                         [5.47705e-05, 5.61145e-05]
# 4391                                      [6.46105e-05]
# 4065  [5.999947343753, 6.999938270025, 10.999905515875]
# 4158                                   [2.999993128397]
# 4173  [5.999963314183, 8.999934026368, 11.999904738552]
# 4143                                   [8.999936088809]
# 3815                                              [0.0]
# 3559    [2.99997315278, 5.999943864894, 8.999914577022]
# 4188                                   [1.000009442421]
# 4203  [1.000009442421, 1.000010882422, 1.00001157042...
# 3544  [2.999973153105, 8.999914559148, 11.999893344587]
# 3499                                              [1.0]
# 3484  [1.0, 1.999983859464, 2.999973153883, 8.999914...
# 3574  [2.999973154048, 5.999943864933, 8.99991457716...
# 4439                                   [0.000271128944]
# 3783                                              [0.0]
# 3589  [2.999973152792, 5.999943864974, 8.99991457716...
# 3619   [1.999982915346, 4.999953628286, 9.999904814527]
# 3649   [2.999973152547, 3.999963389831, 6.999934100584]
# 3759                                              [0.0]
# 3767                                              [0.0]
# 4431                                   [0.000260872884]
# 3775                                              [0.0]
# 4423                                   [0.000259414384]
# 3799                                              [0.0]
# 4407  [9.17305e-05, 9.24025e-05, 9.30745e-05, 1.7090...
# 3823                              [0.0, 6.965934824614]
# 3791                                              [0.0]
# 4455                    [4.53697629044, 4.694974747207]

# %%
prio6_qvs = qvs[['device+port', 'queue', 'max length', 'number of max', 'times of max']].loc[qvs['module'] == "Car.switchRearLeft.eth[4].macLayer.queue.queue[6]"]
for t in prio6_qvs['times of max']:
    print (t)
# Out:
# [ 0.3760051   0.62600266  0.75100144  2.37598557  2.62598313  2.75098192
#   4.12596849  4.25096727  4.62596361  4.75096239  5.62595385  5.75095263
#   6.62594408  6.75094286  7.62593432  7.87593188  8.00093066  8.62592456
#   8.75092334  9.37591724  9.6259148   9.87591235 10.00091113]

# %% [markdown]
# #### plot largest 5 queues per prio

# %%
plts_queues = []
for prio, g in qvs.groupby('queue'):
    plts_queues.append(g.sort_values('max length', ascending=False).head(5))

df_plt_q = pd.concat(plts_queues)

# %%
for idx, row in df_plt_q.loc[df_plt_q['queue'] == "queue[7]"].iterrows():
    plt.plot(row['vectime'], row['vecvalue'], label=row['module'])
    plt.title("Queue sizes for Priority 7 ")
    plt.xlabel("Time [s]")
    plt.ylabel("Queue size [num packets]")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
for idx, row in df_plt_q.loc[df_plt_q['queue'] == "queue[6]"].iterrows():
    plt.plot(row['vectime'], row['vecvalue'], label=row['module'])
    plt.title("Queue sizes for Priority 6 ")
    plt.xlabel("Time [s]")
    plt.ylabel("Queue size [num packets]")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
for idx, row in df_plt_q.loc[df_plt_q['queue'] == "queue[5]"].iterrows():
    plt.plot(row['vectime'], row['vecvalue'], label=row['module'])
    plt.title("Queue sizes for Priority 5 ")
    plt.xlabel("Time [s]")
    plt.ylabel("Queue size [num packets]")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
for idx, row in df_plt_q.loc[df_plt_q['queue'] == "queue[4]"].iterrows():
    plt.plot(row['vectime'], row['vecvalue'], label=row['module'])
    plt.title("Queue sizes for Priority 4 ")
    plt.xlabel("Time [s]")
    plt.ylabel("Queue size [num packets]")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
for idx, row in df_plt_q.loc[df_plt_q['queue'] == "queue[2]"].iterrows():
    plt.plot(row['vectime'], row['vecvalue'], label=row['module'])
    plt.title("Queue sizes for Priority 2 ")
    plt.xlabel("Time [s]")
    plt.ylabel("Queue size [num packets]")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
for idx, row in df_plt_q.loc[df_plt_q['queue'] == "queue[0]"].iterrows():
    plt.plot(row['vectime'], row['vecvalue'], label=row['module'])
    plt.title("Queue sizes for Priority 0 ")
    plt.xlabel("Time [s]")
    plt.ylabel("Queue size [num packets]")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
