# %% [markdown]
# #  Evaluations

# %%
import pandas as pd
import numpy as np
import  matplotlib.pyplot as plt
import re
from omnetpp.scave import results, chart, utils
# %matplotlib inline

# %%
config_vec = "General-*.vec"
config_sca = "General-*.sca"

pre = "General_" # prefix for saved files

read_data_from_results = True

# %% [markdown]
# ## Max Latencies

# %% [markdown]
# ### Function definitions

# %%
def get_device(module):
    return module.split(".")[1]

def get_streamId(module, df):
    # assumning that streamIds are deterministic
    attrname = "*." + module.split(".")[1] + "." + module.split(".")[2] + ".display-name"
    attrval = df.loc[df['attrname'] == attrname,'attrvalue']
    try:
        return attrval.to_list()[0].split(" ")[0]
    except:
        return " "

def streamencodings(df):
    df_notna = df[df['attrname'].notna()]
    all_encodings = df_notna.loc[df_notna['attrname'].str.contains(".bridging.streamCoder.encoder.mapping")]
    # build a single json file based on streamname as key
    encodings = dict()
    for idx, row in all_encodings.iterrows():
        dev = row['attrname']
        encoding_str = row['attrvalue']
        encoding = re.findall(r'\{([^}]*)\}', encoding_str)
        for item in encoding:
            enc = item.split(",")  
            for e in enc:
                if "stream" in e:
                    stream = re.findall('"([^"]*)"', e)[0]
                elif "pcp" in e:
                    pcp = re.findall(r'\d+', e)[0]
                elif "vlan" in e:
                    vlan = re.findall(r'\d+', e)[0]
            # add infos to stream encoding
            if stream in encodings.keys():
                if pcp not in encodings[stream]['pcp']:
                    encodings[stream]['pcp'].append(pcp)
                if vlan not in encodings[stream]['vlan']:
                    encodings[stream]['vlan'].append(vlan)
                if dev not in encodings[stream]['dev']:
                    encodings[stream]['dev'].append(dev)
            else:
                encodings[stream] = {'pcp' : [pcp],
                                    'vlan' : [vlan],
                                    'dev' : [dev]}
    return encodings
        
def set_streamId(name): # streamnames are only sometimes deterministic, these are the special cases
    if "_" in name: # CAN
        return "SControl"
    if name == "SReset": # a single stream that is not formatted the same
        return "SControl"
    if name == " ": # Tcp-Stream
        return "SEtsiCamOut"
    
    return name

def get_pcp(streamname, device , df):
    if "zonalController" in device:
        attrname = "*.zonalController*.bridging.streamCoder.decoder.mapping"
    else:
        attrname = "*." + device + ".bridging.streamCoder.decoder.mapping"
    
    try:
        decoding_str = df.loc[df['attrname']==attrname, 'attrvalue'].to_list()[0]
        decoding = re.findall(r'\{([^}]*)\}', decoding_str)
        # get pcp for the stream from the table
        for item in decoding:
            if (streamname + "\"") in item:
                return item.split(",")[1][-1:]
    except:
        return " "

def get_pcp_from_encodings(streamname, encodings):
    try:
        return encodings[streamname]['pcp'][0]
    except:
        return " "
        

def max_delay(vals):
    try:
        return vals.max()
    except Exception as e:
        print(e)
        return "ERROR"


def extract_e2edelay(df):
    res = df[['runID','module', 'vectime', 'vecvalue']].dropna()
    res['device'] = res.apply(lambda row: get_device(row['module']), axis=1)
    res['streamname'] = res.apply(lambda row: get_streamId(row['module'], df), axis=1)
    res['streamname-Control'] = res.apply(lambda row: set_streamId(row['streamname']), axis=1)
    encodings  = streamencodings(df)
    res['pcp'] = res.apply(lambda row: get_pcp_from_encodings(row['streamname-Control'], encodings), axis=1)
    res['max e2e delay'] = res.apply(lambda row: max_delay(row['vecvalue']), axis=1)
    
    return res

# %% [markdown]
# ### Evaluate latencies and jitter

# %%
# read results
if read_data_from_results:
    res = results.read_result_files(filenames = config_vec,
                                filter_expression = "name =~ meanBitLifeTimePerPacket:vector")
    latencies = extract_e2edelay(res)
    latencies.to_pickle(pre+"latencies_data")
else:
    latencies = pd.read_pickle(pre+"latencies_data")

# %%
latency_jitter_by_priority = []
for prio, group in latencies.groupby('pcp'):
    sorted = group.sort_values('max e2e delay', ascending = False)
    
    max_latency = group['max e2e delay'].max()
    min_latency = group['max e2e delay'].min()
    jitter = max_latency - min_latency

    max_stream = group.loc[group['max e2e delay'] == max_latency, 'module'].to_list()

    latency_jitter_by_priority.append({"pcp": prio,
                                       "max latency [s]": max_latency,
                                       "min latency [s]": min_latency,
                                       "jitter [s]": jitter,
                                       "stream with max latency": max_stream
                                      })

df_latency_prio = pd.DataFrame(latency_jitter_by_priority)

df_latency_prio.to_csv(pre+"latency_by_prio.csv", index=False)
df_latency_prio
# Out:
#   pcp  max latency [s]  min latency [s]  jitter [s]  \
# 0   2         0.000266         0.000136    0.000130
# 1   4         0.000314         0.000005    0.000309
# 2   5         0.000154         0.000065    0.000089
# 3   6         0.000027         0.000007    0.000019
#
#                              stream with max latency
# 0  [Car.connectivityGateway.app[0].connection[0]....
# 1        [Car.zonalControllerRearRight.app[91].sink]
# 2                             [Car.adas.app[2].sink]
# 3          [Car.zonalControllerRearLeft.app[5].sink]

# %% [markdown]
# ### Latencies Prio 6, per stream

# %%
l_p6  = latencies.loc[latencies['pcp'] == "6"].copy()

# %%
l_p6['min e2e delay'] = l_p6.apply(lambda row: row['vecvalue'].min(), axis=1)
l_p6['jitter'] = l_p6.apply(lambda row: row['max e2e delay'] - row['min e2e delay'], axis=1)

# %%
l_p6_streams = l_p6[['module','device', 'streamname', 'max e2e delay', 'min e2e delay', 'jitter']].sort_values('max e2e delay', ascending=False)
l_p6_streams.rename(columns= {'max e2e delay': 'max e2e delay [s]', 'min e2e delay': 'min e2e delay [s]', 'jitter': 'jitter [s]'}, inplace=True)
l_p6_streams.to_csv(pre+"latencies_prio6.csv")

# %%
l_p6_streams
# Out:
#                                          module                     device  \
# 3530    Car.zonalControllerRearLeft.app[5].sink    zonalControllerRearLeft
# 3509    Car.zonalControllerRearLeft.app[2].sink    zonalControllerRearLeft
# 3488    Car.zonalControllerRearLeft.app[4].sink    zonalControllerRearLeft
# 3467    Car.zonalControllerRearLeft.app[1].sink    zonalControllerRearLeft
# 3446    Car.zonalControllerRearLeft.app[3].sink    zonalControllerRearLeft
# 3425    Car.zonalControllerRearLeft.app[0].sink    zonalControllerRearLeft
# 3523  Car.zonalControllerFrontRight.app[5].sink  zonalControllerFrontRight
# 3502  Car.zonalControllerFrontRight.app[2].sink  zonalControllerFrontRight
# 3551   Car.zonalControllerRearRight.app[2].sink   zonalControllerRearRight
# 3481  Car.zonalControllerFrontRight.app[4].sink  zonalControllerFrontRight
# 3460  Car.zonalControllerFrontRight.app[1].sink  zonalControllerFrontRight
# 3544   Car.zonalControllerRearRight.app[1].sink   zonalControllerRearRight
# 3439  Car.zonalControllerFrontRight.app[3].sink  zonalControllerFrontRight
# 3537   Car.zonalControllerFrontLeft.app[5].sink   zonalControllerFrontLeft
# 3516   Car.zonalControllerRearRight.app[0].sink   zonalControllerRearRight
# 3418  Car.zonalControllerFrontRight.app[0].sink  zonalControllerFrontRight
# 3474   Car.zonalControllerRearRight.app[5].sink   zonalControllerRearRight
# 3495   Car.zonalControllerFrontLeft.app[4].sink   zonalControllerFrontLeft
# 3453   Car.zonalControllerFrontLeft.app[3].sink   zonalControllerFrontLeft
# 3432   Car.zonalControllerRearRight.app[4].sink   zonalControllerRearRight
# 3411   Car.zonalControllerRearRight.app[3].sink   zonalControllerRearRight
#
#            streamname  max e2e delay [s]  min e2e delay [s]  jitter [s]
# 3530       SAutoSteer           0.000027           0.000007    0.000020
# 3509     SManualSteer           0.000026           0.000007    0.000019
# 3488       SAutoBrake           0.000025           0.000005    0.000020
# 3467     SManualBrake           0.000024           0.000005    0.000019
# 3446    SAutoThrottle           0.000023           0.000003    0.000020
# 3425  SManualThrottle           0.000022           0.000003    0.000019
# 3523       SAutoSteer           0.000017           0.000007    0.000010
# 3502     SManualSteer           0.000016           0.000007    0.000009
# 3551     SManualSteer           0.000016           0.000012    0.000004
# 3481       SAutoBrake           0.000015           0.000005    0.000010
# 3460     SManualBrake           0.000014           0.000005    0.000009
# 3544     SManualBrake           0.000014           0.000010    0.000004
# 3439    SAutoThrottle           0.000013           0.000003    0.000010
# 3537       SAutoSteer           0.000013           0.000007    0.000005
# 3516  SManualThrottle           0.000013           0.000008    0.000004
# 3418  SManualThrottle           0.000012           0.000003    0.000009
# 3474       SAutoSteer           0.000011           0.000006    0.000005
# 3495       SAutoBrake           0.000011           0.000006    0.000005
# 3453    SAutoThrottle           0.000010           0.000004    0.000006
# 3432       SAutoBrake           0.000009           0.000004    0.000005
# 3411    SAutoThrottle           0.000007           0.000002    0.000005

# %% [markdown]
# ### Latencies Prio 5, per stream

# %%
l_p5  = latencies.loc[latencies['pcp'] == "5"].copy()

l_p5['min e2e delay'] = l_p5.apply(lambda row: row['vecvalue'].min(), axis=1)
l_p5['jitter'] = l_p5.apply(lambda row: row['max e2e delay'] - row['min e2e delay'], axis=1)

l_p5_streams = l_p5[['module','device', 'streamname', 'max e2e delay', 'min e2e delay', 'jitter']].sort_values('max e2e delay', ascending=False)
l_p5_streams.rename(columns= {'max e2e delay': 'max e2e delay [s]', 'min e2e delay': 'min e2e delay [s]', 'jitter': 'jitter [s]'}, inplace=True)
l_p5_streams.to_csv(pre+"latencies_prio5.csv")

l_p5_streams
# Out:
#                     module device        streamname  max e2e delay [s]  \
# 3404  Car.adas.app[2].sink   adas   SLidarFrontLeft           0.000154
# 3397  Car.adas.app[4].sink   adas    SLidarRearLeft           0.000130
# 3390  Car.adas.app[3].sink   adas  SLidarFrontRight           0.000124
# 3376  Car.adas.app[1].sink   adas        SVideoRear           0.000123
# 3369  Car.adas.app[0].sink   adas       SVideoFront           0.000117
# 3383  Car.adas.app[5].sink   adas   SLidarRearRight           0.000065
#
#       min e2e delay [s]  jitter [s]
# 3404           0.000077    0.000077
# 3397           0.000045    0.000085
# 3390           0.000046    0.000078
# 3376           0.000034    0.000089
# 3369           0.000034    0.000082
# 3383           0.000029    0.000035

# %% [markdown]
# ### Latencies Prio 4, per stream

# %%
l_p4  = latencies.loc[latencies['pcp'] == "4"].copy()

l_p4['min e2e delay'] = l_p4.apply(lambda row: row['vecvalue'].min(), axis=1)
l_p4['jitter'] = l_p4.apply(lambda row: row['max e2e delay'] - row['min e2e delay'], axis=1)

l_p4_streams = l_p4[['module','device', 'streamname', 'max e2e delay', 'min e2e delay', 'jitter']].sort_values('max e2e delay', ascending=False)
l_p4_streams.rename(columns= {'max e2e delay': 'max e2e delay [s]', 'min e2e delay': 'min e2e delay [s]', 'jitter': 'jitter [s]'}, inplace=True)
l_p4_streams.to_csv(pre+"latencies_prio4.csv")

l_p4_streams
# Out:
#                                           module                    device  \
# 3663   Car.zonalControllerRearRight.app[91].sink  zonalControllerRearRight
# 3656   Car.zonalControllerRearRight.app[89].sink  zonalControllerRearRight
# 3894  Car.zonalControllerRearRight.app[112].sink  zonalControllerRearRight
# 3887   Car.zonalControllerRearRight.app[87].sink  zonalControllerRearRight
# 3880   Car.zonalControllerRearRight.app[86].sink  zonalControllerRearRight
# ...                                          ...                       ...
# 6315               Car.infotainment.app[45].sink              infotainment
# 6308               Car.infotainment.app[35].sink              infotainment
# 6301               Car.infotainment.app[34].sink              infotainment
# 6294               Car.infotainment.app[22].sink              infotainment
# 5622  Car.zonalControllerFrontLeft.app[122].sink  zonalControllerFrontLeft
#
#          streamname  max e2e delay [s]  min e2e delay [s]  jitter [s]
# 3663     SAirbag_03           0.000314           0.000027    0.000287
# 3656     SAirbag_01           0.000301           0.000026    0.000275
# 3894   SGetriebe_06           0.000300           0.000032    0.000268
# 3887        SACC_10           0.000300           0.000031    0.000268
# 3880        SACC_07           0.000299           0.000031    0.000268
# ...             ...                ...                ...         ...
# 6315  SRear_View_01           0.000026           0.000007    0.000019
# 6308      SKombi_03           0.000021           0.000006    0.000015
# 6301      SKombi_02           0.000020           0.000005    0.000015
# 6294  SEinheiten_01           0.000012           0.000005    0.000008
# 5622   SMainUnit_01           0.000005           0.000001    0.000004
#
# [441 rows x 6 columns]

# %% [markdown]
# ### Evaluate if apps receive data

# %%
def get_appno(module):
    num = re.findall(r'\[.*?\]', module)[0]
    nums = re.findall(r'\d+', num)
    if ".." in num:
        r_nums = []
        for i in range (int(nums[0]), int(nums[1])+1):
            r_nums.append(i)
        return r_nums
    else:
        return nums

# %%
# find all configured sinks
df_sinkapps = res.loc[res['attrvalue'].isin(["UdpSinkApp", "TcpClientApp", "TcpServerApp"]), ['attrname', 'attrvalue']]

configured_sinks = []
for idx, row in df_sinkapps.iterrows():
    if ".." in row['attrname']: # config for multiple apps
        nums = get_appno(row['attrname'])
        for n in nums:
            sink = get_device(row['attrname']) + ".app[" + str(n) + "]"
            configured_sinks.append(sink)
    else:
        sink = get_device(row['attrname']) + ".app[" + re.findall(r'\d+', row['attrname'])[0] + "]"
        configured_sinks.append(sink)

# %%
# find all sinks that received at least one packet that is counted towards latency-results
sinks_receiving_data = latencies['module'].to_list()

# and bring them in same format as configured_strings
sinks_receiving_data_formatted = []
for sink in sinks_receiving_data:
    formatted = sink.split(".")[1] + "." + sink.split(".")[2]
    sinks_receiving_data_formatted.append(formatted)

# %%
# compare the lists

# only configured
diff_conf = []
for s in configured_sinks:
    if s not in sinks_receiving_data_formatted:
        diff_conf.append(s)

diff_conf

# all of these apps do have a 'dropped data rate', if you check them by hand, is this wanted?
# Out:
# []

# %%
# only in results
diff_res = []
for s in sinks_receiving_data_formatted:
    if s not in configured_sinks:
        diff_res.append(s)

diff_res
# Out:
# []

# %% [markdown]
# ## Queueing

# %%
### Function definitions
def get_devicePort(module):
    split = module.split(".")
    return split[1] + "." + split[2]

def get_queueNo(module):
    split = module.split(".")
    if len(split) < 6:
        return "all"
    else:
        return split[5]


def extract_maxq(df):
    res = df[['runID', 'module', 'value']].dropna()
    res.sort_values(by='value', ascending=False, inplace=True)
#res_maxq['device'] = res_maxq.apply(lambda row: get_device(row['module']), axis=1)
    res['device+port'] = res.apply(lambda row: get_devicePort(row['module']), axis=1)
    res['queue'] = res.apply(lambda row: get_queueNo(row['module']), axis=1)
    res = res[['runID','device+port', 'queue', 'value']]
    return res

# %% [markdown]
# ### Max queuelengths

# %%
# read results
if read_data_from_results:
    res_q = results.read_result_files(filenames = config_sca,
                                filter_expression = "module =~ *.eth[*].macLayer.queue* AND name =~ queueLength:max")
    max_q = extract_maxq(res_q)
    max_q.to_pickle(pre+"queues_data")
else:
    max_q = pd.read_pickle(pre+"queues_data")

# %%
# queues by priority

qs = []
for q, group in max_q.groupby('queue'):
    max = group['value'].max()
    port = group.loc[group['value'] == max]
    ports = port['device+port'].to_list()
    if q == "all":
       qs.append({"prio": "all",
                "max": max,
                 "port": ports}) 
    else:
        prio = re.findall(r'\d+', q)[0]
        qs.append({"prio": prio,
                   "max": max,
                   "port": ports})

df_qs = pd.DataFrame(qs)

df_qs
# Out:
#   prio    max                                               port
# 0  all  185.0                  [zonalControllerRearRight.eth[0]]
# 1    0  131.0                  [zonalControllerFrontLeft.eth[0]]
# 2    2    2.0  [switchFrontLeft.eth[0], switchFrontRight.eth[1]]
# 3    4   79.0                  [zonalControllerRearRight.eth[0]]
# 4    5    7.0                           [switchRearRight.eth[2]]
# 5    6   13.0                            [switchRearLeft.eth[4]]
# 6    7    4.0  [switchRearRight.eth[3], switchRearLeft.eth[4]...

# %% [markdown]
# ### Queues over time

# %%
def extract_data_qlen(df):
    res = df[['runID','module', 'vectime', 'vecvalue']].dropna()
    res['device+port'] = res.apply(lambda row: get_devicePort(row['module']), axis=1)
    res['queue'] = res.apply(lambda row: get_queueNo(row['module']), axis=1)
    res['max length'] = res.apply(lambda row: row['vecvalue'].max(), axis=1)
    return res

def set_curmax(vec):
    max = 0
    res = []
    for v in vec:
        if v > max:
            max = v
            res.append(v)
        else:
            res.append(max)
    return res

def get_maxtime(time, vec, max):
    m_idx = [i for i, v in enumerate(vec) if v == max]
    return time[m_idx]

# %%
# read results
if read_data_from_results:
    res_qv = results.read_result_files(filenames = config_vec,
                                filter_expression = "module =~ *macLayer.queue* AND name =~ queueLength:vector")
    qvs = extract_data_qlen(res_qv)
    qvs.to_pickle(pre+"queues_vec_data")
else:
    qvs = pd.read_pickle(pre+"queues_vec_data")

# %% [markdown]
# #### classify behaviour of streams (somehow)...

# %%
qvs['current max'] = qvs.apply(lambda row: set_curmax(row['vecvalue']), axis=1)
qvs['times of max'] = qvs.apply(lambda row: get_maxtime(row['vectime'], row['vecvalue'], row['max length']), axis=1)
qvs['latest time of max'] = qvs.apply(lambda row: row['times of max'].max(), axis=1)
qvs['number of max'] = qvs.apply(lambda row: len(row['times of max']), axis=1)

# %%
# Streams that reach their max in the last second (but max reach it before then too)
qvs_lastsec = qvs[['device+port', 'queue', 'max length']].loc[qvs['latest time of max'] > 9.0].sort_values('max length', ascending=False)
qvs_lastsec.loc[qvs_lastsec['queue'] != "all"]
# Out:
#                            device+port     queue  max length
# 3725  zonalControllerFrontRight.eth[0]  queue[4]        62.0
# 4023             switchRearLeft.eth[4]  queue[6]        13.0
# 3991            switchFrontLeft.eth[1]  queue[4]        13.0
# 4007           switchFrontRight.eth[4]  queue[6]        10.0
# 3906            switchRearRight.eth[3]  queue[6]         9.0
# 4341            switchRearRight.eth[2]  queue[5]         7.0
# 3929            switchFrontLeft.eth[0]  queue[6]         6.0
# 3921            switchRearRight.eth[0]  queue[6]         6.0
# 4317             switchRearLeft.eth[0]  queue[5]         5.0
# 4301           switchFrontRight.eth[0]  queue[5]         5.0
# 4047            switchFrontLeft.eth[4]  queue[6]         5.0
# 3983             switchRearLeft.eth[0]  queue[4]         5.0
# 4015             switchRearLeft.eth[0]  queue[6]         4.0
# 4039             switchRearLeft.eth[1]  queue[6]         4.0
# 4229           switchFrontRight.eth[4]  queue[7]         4.0
# 3805                       adas.eth[0]  queue[6]         3.0
# 3898            switchRearRight.eth[1]  queue[6]         3.0
# 4333            switchFrontLeft.eth[1]  queue[5]         3.0
# 3937            switchFrontLeft.eth[1]  queue[6]         3.0
# 4325            switchFrontLeft.eth[0]  queue[5]         3.0
# 3709   zonalControllerFrontLeft.eth[0]  queue[6]         3.0
# 4176             switchRearLeft.eth[2]  queue[7]         2.0
# 4206            switchFrontLeft.eth[3]  queue[7]         2.0
# 4161           switchFrontRight.eth[2]  queue[7]         2.0
# 4253            switchFrontLeft.eth[5]  queue[7]         2.0
# 4261            switchRearRight.eth[0]  queue[7]         2.0
# 4269            switchRearRight.eth[1]  queue[7]         2.0
# 3369            switchFrontLeft.eth[1]  queue[7]         2.0
# 3773             lidarRearRight.eth[0]  queue[5]         2.0
# 3399           switchFrontRight.eth[0]  queue[7]         2.0
# 3504    zonalControllerRearLeft.eth[0]  queue[7]         2.0
# 4086                masterClock.eth[0]  queue[0]         2.0
# 3757            lidarFrontRight.eth[0]  queue[5]         2.0
# 3765              lidarRearLeft.eth[0]  queue[5]         2.0
# 3749             lidarFrontLeft.eth[0]  queue[5]         2.0
# 3384            switchFrontLeft.eth[0]  queue[7]         2.0
# 3781                cameraFront.eth[0]  queue[5]         1.0
# 3789                 cameraRear.eth[0]  queue[5]         1.0
# 3813                       adas.eth[0]  queue[2]         1.0
# 3999           switchFrontRight.eth[1]  queue[6]         1.0
# 3429             switchRearLeft.eth[0]  queue[7]         1.0
# 3414           switchFrontRight.eth[1]  queue[7]         1.0
# 4070            switchRearRight.eth[1]  queue[2]         1.0
# 4373             switchRearLeft.eth[1]  queue[2]         1.0
# 4381             switchRearLeft.eth[4]  queue[0]         1.0
# 4397            switchFrontLeft.eth[3]  queue[2]         1.0
# 4405        connectivityGateway.eth[0]  queue[2]         1.0
# 4437            switchRearRight.eth[2]  queue[2]         1.0
# 4445            switchRearRight.eth[3]  queue[0]         1.0

# %%
# streams that reach max less than 5 times during runtime
qvs_fewmax =qvs[['device+port', 'queue', 'max length', 'number of max', 'times of max']].loc[qvs['number of max'] < 5].sort_values('max length', ascending=False)
qvs_fewmax.loc[qvs_fewmax['queue'] != "all"]
# Out:
#                            device+port     queue  max length  number of max  \
# 3669   zonalControllerFrontLeft.eth[0]  queue[0]       131.0              1
# 3677  zonalControllerFrontRight.eth[0]  queue[0]       120.0              1
# 3693   zonalControllerRearRight.eth[0]  queue[0]       105.0              1
# 3741   zonalControllerRearRight.eth[0]  queue[4]        79.0              1
# 3829           switchFrontRight.eth[1]  queue[4]        75.0              1
# 3875            switchFrontLeft.eth[0]  queue[4]        55.0              4
# 4357           switchFrontRight.eth[1]  queue[0]        53.0              1
# 3685    zonalControllerRearLeft.eth[0]  queue[0]        46.0              1
# 3717   zonalControllerFrontLeft.eth[0]  queue[4]        43.0              4
# 3821           switchFrontRight.eth[0]  queue[4]        42.0              3
# 3701               infotainment.eth[0]  queue[0]        39.0              1
# 4285            switchFrontLeft.eth[4]  queue[0]        30.0              1
# 4078             switchRearLeft.eth[1]  queue[0]        20.0              1
# 4277            switchFrontLeft.eth[0]  queue[0]        19.0              1
# 3797               infotainment.eth[0]  queue[4]        14.0              2
# 4421           switchFrontRight.eth[4]  queue[0]         9.0              1
# 3733    zonalControllerRearLeft.eth[0]  queue[4]         7.0              4
# 4341            switchRearRight.eth[2]  queue[5]         7.0              2
# 4309             switchRearLeft.eth[1]  queue[5]         6.0              1
# 4293           switchFrontRight.eth[1]  queue[5]         6.0              2
# 4055            switchFrontLeft.eth[5]  queue[4]         5.0              2
# 4365            switchRearRight.eth[1]  queue[0]         5.0              1
# 4349            switchFrontLeft.eth[5]  queue[0]         4.0              2
# 4221            switchFrontLeft.eth[4]  queue[7]         4.0              1
# 4131             switchRearLeft.eth[3]  queue[7]         3.0              3
# 4101            switchFrontLeft.eth[2]  queue[7]         3.0              2
# 4413            switchFrontLeft.eth[0]  queue[2]         2.0              1
# 3459            switchRearRight.eth[5]  queue[7]         2.0              2
# 4031           switchFrontRight.eth[0]  queue[6]         2.0              4
# 4146            switchRearRight.eth[4]  queue[7]         2.0              4
# 3609                 cameraRear.eth[0]  queue[7]         2.0              3
# 3474   zonalControllerFrontLeft.eth[0]  queue[7]         2.0              3
# 3489  zonalControllerFrontRight.eth[0]  queue[7]         2.0              3
# 3519   zonalControllerRearRight.eth[0]  queue[7]         2.0              2
# 3594                cameraFront.eth[0]  queue[7]         2.0              4
# 3654        connectivityGateway.eth[0]  queue[7]         2.0              2
# 3639                       adas.eth[0]  queue[7]         2.0              2
# 4429           switchFrontRight.eth[1]  queue[2]         2.0              1
#
#                                            times of max
# 3669                                              [0.0]
# 3677                                              [0.0]
# 3693                                              [0.0]
# 3741                                              [0.0]
# 3829                                    [6.00003080157]
# 3875  [3.25945e-05, 3.32665e-05, 3.3626e-05, 3.4298e...
# 4357                                      [0.000130258]
# 3685                                              [0.0]
# 3717  [0.0, 2.999970021959, 5.999941423917, 8.999912...
# 3821   [5.999975872786, 5.999977216786, 5.999977888786]
# 3701                                              [0.0]
# 4285                                      [0.000104586]
# 4078                                      [3.50425e-05]
# 4277                                      [9.64345e-05]
# 3797                              [0.0, 8.999912134341]
# 4421                                      [0.000107234]
# 3733  [0.0, 2.999970709781, 5.999941423646, 8.999912...
# 4341                   [5.436163812264, 9.486725720009]
# 4309                                     [0.0316657465]
# 4293                    [3.426132297189, 8.00033764175]
# 4055                   [4.999976860781, 4.999977532781]
# 4365                                      [6.46105e-05]
# 4349                         [5.47705e-05, 5.61145e-05]
# 4221                                   [1.000012675023]
# 4131   [2.999992536397, 2.999993128397, 8.999934552765]
# 4101                   [5.999963250258, 5.999963842258]
# 4413                                       [0.00026724]
# 3459                                         [0.0, 1.0]
# 4031  [0.125003645711, 0.125004621711, 0.25000242537...
# 4146  [9.4425e-06, 1.000009442421, 2.999992538606, 8...
# 3609                         [0.0, 1.0, 1.999982915363]
# 3474                         [0.0, 1.0, 1.999983859687]
# 3489                         [0.0, 1.0, 7.999924339248]
# 3519                                         [0.0, 1.0]
# 3594         [0.0, 1.0, 7.999924339792, 8.999914577188]
# 3654                                         [0.0, 1.0]
# 3639                                         [0.0, 1.0]
# 4429                                   [0.000271224944]

# %%
prio6_qvs = qvs[['device+port', 'queue', 'max length', 'number of max', 'times of max']].loc[qvs['module'] == "Car.switchRearLeft.eth[4].macLayer.queue.queue[6]"]
for t in prio6_qvs['times of max']:
    print (t)
# Out:
# [0.3760051  0.62600266 0.75100144 1.6259929  1.75099172 2.37598557
#  2.62598313 2.75098192 3.12597825 3.25097703 3.62597337 3.75097215
#  4.62596361 4.75096239 5.12595873 5.25095751 6.37594652 6.62594408
#  6.75094286 7.62593432 7.7509331  8.375927   8.62592456 8.75092334
#  9.12591968 9.25091846 9.87591235]

# %% [markdown]
# #### plot largest 5 queues per prio

# %%
plts_queues = []
for prio, g in qvs.groupby('queue'):
    plts_queues.append(g.sort_values('max length', ascending=False).head(5))

df_plt_q = pd.concat(plts_queues)

# %%
for idx, row in df_plt_q.loc[df_plt_q['queue'] == "queue[7]"].iterrows():
    plt.plot(row['vectime'], row['vecvalue'], label=row['module'])
    plt.title("Queue sizes for Priority 7 ")
    plt.xlabel("Time [s]")
    plt.ylabel("Queue size [num packets]")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
for idx, row in df_plt_q.loc[df_plt_q['queue'] == "queue[6]"].iterrows():
    plt.plot(row['vectime'], row['vecvalue'], label=row['module'])
    plt.title("Queue sizes for Priority 6 ")
    plt.xlabel("Time [s]")
    plt.ylabel("Queue size [num packets]")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
for idx, row in df_plt_q.loc[df_plt_q['queue'] == "queue[5]"].iterrows():
    plt.plot(row['vectime'], row['vecvalue'], label=row['module'])
    plt.title("Queue sizes for Priority 5 ")
    plt.xlabel("Time [s]")
    plt.ylabel("Queue size [num packets]")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
for idx, row in df_plt_q.loc[df_plt_q['queue'] == "queue[4]"].iterrows():
    plt.plot(row['vectime'], row['vecvalue'], label=row['module'])
    plt.title("Queue sizes for Priority 4 ")
    plt.xlabel("Time [s]")
    plt.ylabel("Queue size [num packets]")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
for idx, row in df_plt_q.loc[df_plt_q['queue'] == "queue[2]"].iterrows():
    plt.plot(row['vectime'], row['vecvalue'], label=row['module'])
    plt.title("Queue sizes for Priority 2 ")
    plt.xlabel("Time [s]")
    plt.ylabel("Queue size [num packets]")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
for idx, row in df_plt_q.loc[df_plt_q['queue'] == "queue[0]"].iterrows():
    plt.plot(row['vectime'], row['vecvalue'], label=row['module'])
    plt.title("Queue sizes for Priority 0 ")
    plt.xlabel("Time [s]")
    plt.ylabel("Queue size [num packets]")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
