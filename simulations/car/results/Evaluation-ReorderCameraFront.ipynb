# %% [markdown]
# #  Evaluations - Reorder camera front

# %%
import pandas as pd
import numpy as np
import  matplotlib.pyplot as plt
import re
from omnetpp.scave import results, chart, utils
# %matplotlib inline

# %%
config_vec = "ReorderCameraFront-*.vec"
config_sca = "ReorderCameraFront-*.sca"

pre = "ReorderCameraFront_" # prefix for saved files

read_data_from_results = True

# %% [markdown]
# ## Max Latencies

# %% [markdown]
# ### Function definitions

# %%
def get_device(module):
    return module.split(".")[1]

def get_streamId(module, df):
    # assumning that streamIds are deterministic
    attrname = "*." + module.split(".")[1] + "." + module.split(".")[2] + ".display-name"
    attrval = df.loc[df['attrname'] == attrname,'attrvalue']
    try:
        return attrval.to_list()[0].split(" ")[0]
    except:
        return " "

def streamencodings(df):
    df_notna = df[df['attrname'].notna()]
    all_encodings = df_notna.loc[df_notna['attrname'].str.contains(".bridging.streamCoder.encoder.mapping")]
    # build a single json file based on streamname as key
    encodings = dict()
    for idx, row in all_encodings.iterrows():
        dev = row['attrname']
        encoding_str = row['attrvalue']
        encoding = re.findall(r'\{([^}]*)\}', encoding_str)
        for item in encoding:
            enc = item.split(",")  
            for e in enc:
                if "stream" in e:
                    stream = re.findall('"([^"]*)"', e)[0]
                elif "pcp" in e:
                    pcp = re.findall(r'\d+', e)[0]
                elif "vlan" in e:
                    vlan = re.findall(r'\d+', e)[0]
            # add infos to stream encoding
            if stream in encodings.keys():
                if pcp not in encodings[stream]['pcp']:
                    encodings[stream]['pcp'].append(pcp)
                if vlan not in encodings[stream]['vlan']:
                    encodings[stream]['vlan'].append(vlan)
                if dev not in encodings[stream]['dev']:
                    encodings[stream]['dev'].append(dev)
            else:
                encodings[stream] = {'pcp' : [pcp],
                                    'vlan' : [vlan],
                                    'dev' : [dev]}
    return encodings
        
def set_streamId(name): # streamnames are only sometimes deterministic, these are the special cases
    if "_" in name: # CAN
        return "SControl"
    if name == "SReset": # a single stream that is not formatted the same
        return "SControl"
    if name == " ": # Tcp-Stream
        return "SEtsiCamOut"
    
    return name

def get_pcp(streamname, device , df):
    if "zonalController" in device:
        attrname = "*.zonalController*.bridging.streamCoder.decoder.mapping"
    else:
        attrname = "*." + device + ".bridging.streamCoder.decoder.mapping"
    
    try:
        decoding_str = df.loc[df['attrname']==attrname, 'attrvalue'].to_list()[0]
        decoding = re.findall(r'\{([^}]*)\}', decoding_str)
        # get pcp for the stream from the table
        for item in decoding:
            if (streamname + "\"") in item:
                return item.split(",")[1][-1:]
    except:
        return " "

def get_pcp_from_encodings(streamname, encodings):
    try:
        return encodings[streamname]['pcp'][0]
    except:
        return " "
        

def max_delay(vals):
    try:
        return vals.max()
    except Exception as e:
        print(e)
        return "ERROR"


def extract_e2edelay(df):
    res = df[['runID','module', 'vectime', 'vecvalue']].dropna()
    res['device'] = res.apply(lambda row: get_device(row['module']), axis=1)
    res['streamname'] = res.apply(lambda row: get_streamId(row['module'], df), axis=1)
    res['streamname-Control'] = res.apply(lambda row: set_streamId(row['streamname']), axis=1)
    encodings  = streamencodings(df)
    res['pcp'] = res.apply(lambda row: get_pcp_from_encodings(row['streamname-Control'], encodings), axis=1)
    res['max e2e delay'] = res.apply(lambda row: max_delay(row['vecvalue']), axis=1)
    
    return res

# %% [markdown]
# ### Evaluate latencies and jitter

# %%
# read results
if read_data_from_results:
    res = results.read_result_files(filenames = config_vec,
                                filter_expression = "name =~ meanBitLifeTimePerPacket:vector")
    latencies = extract_e2edelay(res)
    latencies.to_pickle(pre+"latencies_data")
else:
    latencies = pd.read_pickle(pre+"latencies_data")

# %%
latency_jitter_by_priority = []
for prio, group in latencies.groupby('pcp'):
    sorted = group.sort_values('max e2e delay', ascending = False)
    
    max_latency = group['max e2e delay'].max()
    min_latency = group['max e2e delay'].min()
    jitter = max_latency - min_latency

    max_stream = group.loc[group['max e2e delay'] == max_latency, 'module'].to_list()

    latency_jitter_by_priority.append({"pcp": prio,
                                       "max latency [s]": max_latency,
                                       "min latency [s]": min_latency,
                                       "jitter [s]": jitter,
                                       "stream with max latency": max_stream
                                      })

df_latency_prio = pd.DataFrame(latency_jitter_by_priority)

df_latency_prio.to_csv(pre+"latency_by_prio.csv", index=False)
df_latency_prio
# Out:
#   pcp  max latency [s]  min latency [s]  jitter [s]  \
# 0   2         0.000224         0.000064    0.000160
# 1   4         0.000254         0.000005    0.000250
# 2   5         0.000181         0.000060    0.000121
# 3   6         0.062125         0.000033    0.062092
#
#                              stream with max latency
# 0  [Car.connectivityGateway.app[0].connection[0]....
# 1        [Car.zonalControllerRearRight.app[91].sink]
# 2                             [Car.adas.app[0].sink]
# 3          [Car.zonalControllerRearLeft.app[2].sink]

# %% [markdown]
# ### Latencies Prio 6, per stream

# %%
l_p6  = latencies.loc[latencies['pcp'] == "6"].copy()

# %%
l_p6['min e2e delay'] = l_p6.apply(lambda row: row['vecvalue'].min(), axis=1)
l_p6['jitter'] = l_p6.apply(lambda row: row['max e2e delay'] - row['min e2e delay'], axis=1)

# %%
l_p6_streams = l_p6[['module','device', 'streamname', 'max e2e delay', 'min e2e delay', 'jitter']].sort_values('max e2e delay', ascending=False)
l_p6_streams.rename(columns= {'max e2e delay': 'max e2e delay [s]', 'min e2e delay': 'min e2e delay [s]', 'jitter': 'jitter [s]'}, inplace=True)
l_p6_streams.to_csv(pre+"latencies_prio6.csv")

# %%
l_p6_streams
# Out:
#                                          module                     device  \
# 3513    Car.zonalControllerRearLeft.app[2].sink    zonalControllerRearLeft
# 3569   Car.zonalControllerRearRight.app[2].sink   zonalControllerRearRight
# 3485    Car.zonalControllerRearLeft.app[1].sink    zonalControllerRearLeft
# 3457    Car.zonalControllerRearLeft.app[0].sink    zonalControllerRearLeft
# 3555   Car.zonalControllerRearRight.app[1].sink   zonalControllerRearRight
# 3541   Car.zonalControllerRearRight.app[0].sink   zonalControllerRearRight
# 3562   Car.zonalControllerFrontLeft.app[5].sink   zonalControllerFrontLeft
# 3548   Car.zonalControllerFrontLeft.app[4].sink   zonalControllerFrontLeft
# 3534   Car.zonalControllerFrontLeft.app[3].sink   zonalControllerFrontLeft
# 3527    Car.zonalControllerRearLeft.app[5].sink    zonalControllerRearLeft
# 3506  Car.zonalControllerFrontRight.app[2].sink  zonalControllerFrontRight
# 3520  Car.zonalControllerFrontRight.app[5].sink  zonalControllerFrontRight
# 3499    Car.zonalControllerRearLeft.app[4].sink    zonalControllerRearLeft
# 3478  Car.zonalControllerFrontRight.app[1].sink  zonalControllerFrontRight
# 3492  Car.zonalControllerFrontRight.app[4].sink  zonalControllerFrontRight
# 3471    Car.zonalControllerRearLeft.app[3].sink    zonalControllerRearLeft
# 3450  Car.zonalControllerFrontRight.app[0].sink  zonalControllerFrontRight
# 3464  Car.zonalControllerFrontRight.app[3].sink  zonalControllerFrontRight
# 3443   Car.zonalControllerRearRight.app[5].sink   zonalControllerRearRight
# 3436   Car.zonalControllerRearRight.app[4].sink   zonalControllerRearRight
# 3429   Car.zonalControllerRearRight.app[3].sink   zonalControllerRearRight
#
#            streamname  max e2e delay [s]  min e2e delay [s]  jitter [s]
# 3513     SManualSteer           0.062125           0.000066    0.062059
# 3569     SManualSteer           0.062095           0.000095    0.062000
# 3485     SManualBrake           0.061129           0.000064    0.061065
# 3457  SManualThrottle           0.061127           0.000062    0.061065
# 3555     SManualBrake           0.061099           0.000094    0.061005
# 3541  SManualThrottle           0.061097           0.000093    0.061004
# 3562       SAutoSteer           0.000099           0.000096    0.000003
# 3548       SAutoBrake           0.000097           0.000094    0.000003
# 3534    SAutoThrottle           0.000095           0.000092    0.000003
# 3527       SAutoSteer           0.000069           0.000065    0.000003
# 3506     SManualSteer           0.000069           0.000066    0.000003
# 3520       SAutoSteer           0.000068           0.000065    0.000003
# 3499       SAutoBrake           0.000067           0.000063    0.000003
# 3478     SManualBrake           0.000067           0.000064    0.000003
# 3492       SAutoBrake           0.000066           0.000063    0.000003
# 3471    SAutoThrottle           0.000065           0.000061    0.000003
# 3450  SManualThrottle           0.000065           0.000062    0.000003
# 3464    SAutoThrottle           0.000065           0.000061    0.000003
# 3443       SAutoSteer           0.000037           0.000034    0.000003
# 3436       SAutoBrake           0.000035           0.000032    0.000003
# 3429    SAutoThrottle           0.000033           0.000030    0.000003

# %% [markdown]
# ### Latencies Prio 5, per stream

# %%
l_p5  = latencies.loc[latencies['pcp'] == "5"].copy()

l_p5['min e2e delay'] = l_p5.apply(lambda row: row['vecvalue'].min(), axis=1)
l_p5['jitter'] = l_p5.apply(lambda row: row['max e2e delay'] - row['min e2e delay'], axis=1)

l_p5_streams = l_p5[['module','device', 'streamname', 'max e2e delay', 'min e2e delay', 'jitter']].sort_values('max e2e delay', ascending=False)
l_p5_streams.rename(columns= {'max e2e delay': 'max e2e delay [s]', 'min e2e delay': 'min e2e delay [s]', 'jitter': 'jitter [s]'}, inplace=True)
l_p5_streams.to_csv(pre+"latencies_prio5.csv")

l_p5_streams
# Out:
#                     module device        streamname  max e2e delay [s]  \
# 3387  Car.adas.app[0].sink   adas       SVideoFront           0.000181
# 3422  Car.adas.app[2].sink   adas   SLidarFrontLeft           0.000157
# 3415  Car.adas.app[4].sink   adas    SLidarRearLeft           0.000131
# 3408  Car.adas.app[3].sink   adas  SLidarFrontRight           0.000126
# 3394  Car.adas.app[1].sink   adas        SVideoRear           0.000118
# 3401  Car.adas.app[5].sink   adas   SLidarRearRight           0.000060
#
#       min e2e delay [s]  jitter [s]
# 3387           0.000034    0.000147
# 3422           0.000077    0.000080
# 3415           0.000047    0.000084
# 3408           0.000046    0.000079
# 3394           0.000034    0.000084
# 3401           0.000029    0.000030

# %% [markdown]
# ### Latencies Prio 4, per stream

# %%
l_p4  = latencies.loc[latencies['pcp'] == "4"].copy()

l_p4['min e2e delay'] = l_p4.apply(lambda row: row['vecvalue'].min(), axis=1)
l_p4['jitter'] = l_p4.apply(lambda row: row['max e2e delay'] - row['min e2e delay'], axis=1)

l_p4_streams = l_p4[['module','device', 'streamname', 'max e2e delay', 'min e2e delay', 'jitter']].sort_values('max e2e delay', ascending=False)
l_p4_streams.rename(columns= {'max e2e delay': 'max e2e delay [s]', 'min e2e delay': 'min e2e delay [s]', 'jitter': 'jitter [s]'}, inplace=True)
l_p4_streams.to_csv(pre+"latencies_prio4.csv")

l_p4_streams
# Out:
#                                           module                    device  \
# 3681   Car.zonalControllerRearRight.app[91].sink  zonalControllerRearRight
# 3674   Car.zonalControllerRearRight.app[89].sink  zonalControllerRearRight
# 3912  Car.zonalControllerRearRight.app[112].sink  zonalControllerRearRight
# 3905   Car.zonalControllerRearRight.app[87].sink  zonalControllerRearRight
# 3898   Car.zonalControllerRearRight.app[86].sink  zonalControllerRearRight
# ...                                          ...                       ...
# 5206  Car.zonalControllerRearRight.app[111].sink  zonalControllerRearRight
# 5010  Car.zonalControllerFrontLeft.app[137].sink  zonalControllerFrontLeft
# 4989  Car.zonalControllerFrontLeft.app[136].sink  zonalControllerFrontLeft
# 4975  Car.zonalControllerFrontLeft.app[135].sink  zonalControllerFrontLeft
# 5640  Car.zonalControllerFrontLeft.app[122].sink  zonalControllerFrontLeft
#
#         streamname  max e2e delay [s]  min e2e delay [s]  jitter [s]
# 3681    SAirbag_03           0.000254           0.000006    0.000248
# 3674    SAirbag_01           0.000242           0.000005    0.000237
# 3912  SGetriebe_06           0.000242           0.000010    0.000232
# 3905       SACC_10           0.000241           0.000009    0.000232
# 3898       SACC_07           0.000240           0.000007    0.000233
# ...            ...                ...                ...         ...
# 5206   SGateway_79           0.000015           0.000002    0.000014
# 5010    SNavPos_01           0.000012           0.000003    0.000010
# 4989   SNavData_02           0.000011           0.000002    0.000009
# 4975   SNavData_01           0.000010           0.000001    0.000009
# 5640  SMainUnit_01           0.000005           0.000001    0.000004
#
# [441 rows x 6 columns]

# %% [markdown]
# ### latencies per prio

# %%
latencies_extend = latencies.copy()
latencies_extend['min e2e delay'] = latencies_extend.apply(lambda row: row['vecvalue'].min(), axis=1)
latencies_extend['jitter'] = latencies_extend.apply(lambda row: row['max e2e delay'] - row['min e2e delay'], axis=1)

lat = []
for prio, group in latencies_extend.groupby('pcp'):
    max_delay = group['max e2e delay'].max()
    max_d_stream = group.loc[group['max e2e delay'] == max_delay, 'module'].to_list()
    max_jitter = group['jitter'].max()
    max_j_stream = group.loc[group['jitter'] == max_jitter, 'module'].to_list()

    lat.append({"pcp": prio,
               "max latency [s]": max_delay,
               "streams with max latency": max_d_stream,
               "max jitter [s]": max_jitter,
               "streams with max jitter": max_j_stream})

latencies_pcp = pd.DataFrame(lat)

latencies_pcp.to_csv(pre+"latency_jitter_pcp.csv", index=False)

latencies_pcp
# Out:
#   pcp  max latency [s]                           streams with max latency  \
# 0   2         0.000224  [Car.connectivityGateway.app[0].connection[0]....
# 1   4         0.000254        [Car.zonalControllerRearRight.app[91].sink]
# 2   5         0.000181                             [Car.adas.app[0].sink]
# 3   6         0.062125          [Car.zonalControllerRearLeft.app[2].sink]
#
#    max jitter [s]                            streams with max jitter
# 0        0.000221  [Car.connectivityGateway.app[0].connection[0]....
# 1        0.000248        [Car.zonalControllerRearRight.app[91].sink]
# 2        0.000147                             [Car.adas.app[0].sink]
# 3        0.062059          [Car.zonalControllerRearLeft.app[2].sink]

# %% [markdown]
# ### Evaluate if apps receive data

# %%
def get_appno(module):
    num = re.findall(r'\[.*?\]', module)[0]
    nums = re.findall(r'\d+', num)
    if ".." in num:
        r_nums = []
        for i in range (int(nums[0]), int(nums[1])+1):
            r_nums.append(i)
        return r_nums
    else:
        return nums

# %%
# find all configured sinks
df_sinkapps = res.loc[res['attrvalue'].isin(["UdpSinkApp", "TcpClientApp", "TcpServerApp"]), ['attrname', 'attrvalue']]

configured_sinks = []
for idx, row in df_sinkapps.iterrows():
    if ".." in row['attrname']: # config for multiple apps
        nums = get_appno(row['attrname'])
        for n in nums:
            sink = get_device(row['attrname']) + ".app[" + str(n) + "]"
            configured_sinks.append(sink)
    else:
        sink = get_device(row['attrname']) + ".app[" + re.findall(r'\d+', row['attrname'])[0] + "]"
        configured_sinks.append(sink)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # find all configured sinks
# ----> 2 df_sinkapps = res.loc[res['attrvalue'].isin(["UdpSinkApp", "TcpClientApp", "TcpServerApp"]), ['attrname', 'attrvalue']]
#       4 configured_sinks = []
#       5 for idx, row in df_sinkapps.iterrows():
#
# NameError: name 'res' is not defined

# %%
# find all sinks that received at least one packet that is counted towards latency-results
sinks_receiving_data = latencies['module'].to_list()

# and bring them in same format as configured_strings
sinks_receiving_data_formatted = []
for sink in sinks_receiving_data:
    formatted = sink.split(".")[1] + "." + sink.split(".")[2]
    sinks_receiving_data_formatted.append(formatted)

# %%
# compare the lists

# only configured
diff_conf = []
for s in configured_sinks:
    if s not in sinks_receiving_data_formatted:
        diff_conf.append(s)

diff_conf

# all of these apps do have a 'dropped data rate', if you check them by hand, is this wanted?

# %%
# only in results
diff_res = []
for s in sinks_receiving_data_formatted:
    if s not in configured_sinks:
        diff_res.append(s)

diff_res

# %% [markdown]
# ## Queueing

# %% [markdown]
# ### Function definitions

# %%
### Function definitions
def get_devicePort(module):
    split = module.split(".")
    return split[1] + "." + split[2]

def get_queueNo(module):
    split = module.split(".")
    if len(split) < 6:
        return "all"
    else:
        return split[5]


def extract_maxq(df):
    res = df[['runID', 'module', 'value']].dropna()
    res.sort_values(by='value', ascending=False, inplace=True)
#res_maxq['device'] = res_maxq.apply(lambda row: get_device(row['module']), axis=1)
    res['device+port'] = res.apply(lambda row: get_devicePort(row['module']), axis=1)
    res['queue'] = res.apply(lambda row: get_queueNo(row['module']), axis=1)
    res = res[['runID','device+port', 'queue', 'value']]
    return res

# %% [markdown]
# ### Max queuelengths

# %%
# read results
if read_data_from_results:
    res_q = results.read_result_files(filenames = config_sca,
                                filter_expression = "module =~ *.eth[*].macLayer.queue* AND name =~ queueLength:max")
    max_q = extract_maxq(res_q)
    max_q.to_pickle(pre+"queues_data")
else:
    max_q = pd.read_pickle(pre+"queues_data")

# %%
# queues by priority

qs = []
for q, group in max_q.groupby('queue'):
    max = group['value'].max()
    port = group.loc[group['value'] == max]
    ports = port['device+port'].to_list()
    if q == "all":
       qs.append({"prio": "all",
                "max": max,
                 "port": ports}) 
    else:
        prio = re.findall(r'\d+', q)[0]
        qs.append({"prio": prio,
                   "max": max,
                   "port": ports})

df_qs = pd.DataFrame(qs)

df_qs
# Out:
#   prio    max                                               port
# 0  all  251.0                          [switchFrontRight.eth[1]]
# 1    0  131.0                  [zonalControllerFrontLeft.eth[0]]
# 2    2    1.0  [adas.eth[0], switchFrontLeft.eth[0], connecti...
# 3    4   79.0                  [zonalControllerRearRight.eth[0]]
# 4    5    7.0                           [switchRearRight.eth[2]]
# 5    6  187.0                          [switchFrontRight.eth[1]]
# 6    7    4.0                           [switchRearRight.eth[2]]

# %% [markdown]
# ### Queues over time

# %%
def extract_data_qlen(df):
    res = df[['runID','module', 'vectime', 'vecvalue']].dropna()
    res['device+port'] = res.apply(lambda row: get_devicePort(row['module']), axis=1)
    res['queue'] = res.apply(lambda row: get_queueNo(row['module']), axis=1)
    res['max length'] = res.apply(lambda row: row['vecvalue'].max(), axis=1)
    return res

def set_curmax(vec):
    max = 0
    res = []
    for v in vec:
        if v > max:
            max = v
            res.append(v)
        else:
            res.append(max)
    return res

def get_maxtime(time, vec, max):
    m_idx = [i for i, v in enumerate(vec) if v == max]
    return time[m_idx]

# %%
# read results
if read_data_from_results:
    res_qv = results.read_result_files(filenames = config_vec,
                                filter_expression = "module =~ *macLayer.queue* AND name =~ queueLength:vector")
    qvs = extract_data_qlen(res_qv)
    qvs.to_pickle(pre+"queues_vec_data")
else:
    qvs = pd.read_pickle(pre+"queues_vec_data")

# %% [markdown]
# #### classify behaviour of streams (somehow)...

# %%
qvs['current max'] = qvs.apply(lambda row: set_curmax(row['vecvalue']), axis=1)
qvs['times of max'] = qvs.apply(lambda row: get_maxtime(row['vectime'], row['vecvalue'], row['max length']), axis=1)
qvs['latest time of max'] = qvs.apply(lambda row: row['times of max'].max(), axis=1)
qvs['number of max'] = qvs.apply(lambda row: len(row['times of max']), axis=1)

# %%
# Streams that reach their max in the last second (but max reach it before then too)
qvs_lastsec = qvs[['device+port', 'queue', 'max length']].loc[qvs['latest time of max'] > 9.0].sort_values('max length', ascending=False)
qvs_lastsec.loc[qvs_lastsec['queue'] != "all"]
# Out:
#                           device+port     queue  max length
# 4311          switchFrontRight.eth[1]  queue[6]       187.0
# 3908          switchFrontRight.eth[1]  queue[4]        73.0
# 3735  zonalControllerFrontLeft.eth[0]  queue[4]        43.0
# 3971          switchFrontRight.eth[4]  queue[4]        41.0
# 3900          switchFrontRight.eth[0]  queue[4]        23.0
# 3963           switchRearRight.eth[3]  queue[4]        12.0
# 3924           switchRearRight.eth[0]  queue[4]         8.0
# 4033           switchFrontLeft.eth[5]  queue[4]         8.0
# 4303           switchRearRight.eth[2]  queue[5]         7.0
# 4399           switchFrontLeft.eth[4]  queue[6]         6.0
# 4335            switchRearLeft.eth[4]  queue[6]         6.0
# 4319          switchFrontRight.eth[4]  queue[6]         6.0
# 3870           switchRearRight.eth[3]  queue[6]         6.0
# 4263          switchFrontRight.eth[0]  queue[5]         5.0
# 4001            switchRearLeft.eth[0]  queue[4]         5.0
# 3855           switchRearRight.eth[1]  queue[6]         3.0
# 4351          switchFrontRight.eth[0]  queue[6]         3.0
# 4343            switchRearLeft.eth[1]  queue[6]         3.0
# 4327            switchRearLeft.eth[0]  queue[6]         3.0
# 3885           switchRearRight.eth[0]  queue[6]         3.0
# 3839           switchFrontLeft.eth[0]  queue[6]         3.0
# 3847           switchFrontLeft.eth[1]  queue[6]         3.0
# 4287           switchFrontLeft.eth[0]  queue[5]         3.0
# 4295           switchFrontLeft.eth[1]  queue[5]         3.0
# 4056               masterClock.eth[0]  queue[0]         2.0
# 4155          switchFrontRight.eth[2]  queue[7]         2.0
# 4232           switchFrontLeft.eth[4]  queue[7]         2.0
# 3402           switchFrontLeft.eth[0]  queue[7]         2.0
# 3597            lidarRearRight.eth[0]  queue[7]         2.0
# 3627                cameraRear.eth[0]  queue[7]         2.0
# 3492  zonalControllerFrontLeft.eth[0]  queue[7]         2.0
# 3567           lidarFrontRight.eth[0]  queue[7]         2.0
# 3582             lidarRearLeft.eth[0]  queue[7]         2.0
# 3417          switchFrontRight.eth[0]  queue[7]         2.0
# 3612               cameraFront.eth[0]  queue[7]         2.0
# 3727  zonalControllerFrontLeft.eth[0]  queue[6]         2.0
# 3767            lidarFrontLeft.eth[0]  queue[5]         2.0
# 3823                      adas.eth[0]  queue[6]         2.0
# 3477           switchRearRight.eth[5]  queue[7]         1.0
# 4367            switchRearLeft.eth[1]  queue[2]         1.0
# 3432          switchFrontRight.eth[1]  queue[7]         1.0
# 4439           switchFrontLeft.eth[0]  queue[2]         1.0
# 4447          switchFrontRight.eth[1]  queue[2]         1.0
# 3447            switchRearLeft.eth[0]  queue[7]         1.0
# 4025           switchRearRight.eth[1]  queue[2]         1.0
# 4216           switchRearRight.eth[1]  queue[7]         1.0
# 4208           switchRearRight.eth[0]  queue[7]         1.0
# 3672       connectivityGateway.eth[0]  queue[7]         1.0
# 4463           switchRearRight.eth[2]  queue[2]         1.0
# 4423           switchFrontLeft.eth[3]  queue[2]         0.0

# %%
# streams that reach max less than 5 times during runtime
qvs_fewmax =qvs[['device+port', 'queue', 'max length', 'number of max', 'times of max']].loc[qvs['number of max'] < 5].sort_values('max length', ascending=False)
qvs_fewmax.loc[qvs_fewmax['queue'] != "all"]
# Out:
#                            device+port     queue  max length  number of max  \
# 3687   zonalControllerFrontLeft.eth[0]  queue[0]       131.0              1
# 3695  zonalControllerFrontRight.eth[0]  queue[0]       120.0              1
# 3711   zonalControllerRearRight.eth[0]  queue[0]       105.0              1
# 3759   zonalControllerRearRight.eth[0]  queue[4]        79.0              1
# 3743  zonalControllerFrontRight.eth[0]  queue[4]        62.0              1
# 4383           switchFrontRight.eth[1]  queue[0]        52.0              1
# 4224            switchFrontLeft.eth[4]  queue[0]        48.0              2
# 3703    zonalControllerRearLeft.eth[0]  queue[0]        46.0              1
# 3940            switchFrontLeft.eth[0]  queue[4]        41.0              1
# 3971           switchFrontRight.eth[4]  queue[4]        41.0              2
# 3719               infotainment.eth[0]  queue[0]        39.0              1
# 3916             switchRearLeft.eth[1]  queue[4]        30.0              3
# 3900           switchFrontRight.eth[0]  queue[4]        23.0              1
# 4048             switchRearLeft.eth[1]  queue[0]        19.0              1
# 3815               infotainment.eth[0]  queue[4]        14.0              1
# 4017            switchFrontLeft.eth[0]  queue[0]        13.0              1
# 4009            switchFrontLeft.eth[1]  queue[4]        12.0              1
# 3963            switchRearRight.eth[3]  queue[4]        12.0              1
# 4033            switchFrontLeft.eth[5]  queue[4]         8.0              4
# 3751    zonalControllerRearLeft.eth[0]  queue[4]         7.0              1
# 4359           switchFrontRight.eth[4]  queue[0]         7.0              1
# 4271             switchRearLeft.eth[1]  queue[5]         6.0              1
# 4407             switchRearLeft.eth[4]  queue[0]         5.0              1
# 4095            switchFrontLeft.eth[2]  queue[7]         3.0              2
# 4079             switchRearLeft.eth[4]  queue[7]         3.0              4
# 4071           switchFrontRight.eth[4]  queue[7]         3.0              4
# 4125             switchRearLeft.eth[3]  queue[7]         3.0              2
# 4193            switchFrontLeft.eth[3]  queue[7]         3.0              3
# 4170             switchRearLeft.eth[2]  queue[7]         3.0              2
# 4185            switchFrontLeft.eth[5]  queue[7]         3.0              1
# 3387            switchFrontLeft.eth[1]  queue[7]         3.0              1
# 3627                 cameraRear.eth[0]  queue[7]         2.0              2
# 3417           switchFrontRight.eth[0]  queue[7]         2.0              2
# 4391            switchRearRight.eth[1]  queue[0]         2.0              4
# 3462             switchRearLeft.eth[1]  queue[7]         2.0              3
# 4375            switchFrontLeft.eth[5]  queue[0]         2.0              2
# 3507  zonalControllerFrontRight.eth[0]  queue[7]         2.0              2
# 3552             lidarFrontLeft.eth[0]  queue[7]         2.0              2
# 3567            lidarFrontRight.eth[0]  queue[7]         2.0              4
# 3582              lidarRearLeft.eth[0]  queue[7]         2.0              4
# 3597             lidarRearRight.eth[0]  queue[7]         2.0              4
# 3612                cameraFront.eth[0]  queue[7]         2.0              3
# 4455            switchFrontLeft.eth[1]  queue[0]         2.0              1
# 3642               infotainment.eth[0]  queue[7]         2.0              1
# 4140            switchRearRight.eth[4]  queue[7]         2.0              1
# 3657                       adas.eth[0]  queue[7]         2.0              1
# 3767             lidarFrontLeft.eth[0]  queue[5]         2.0              3
# 3775            lidarFrontRight.eth[0]  queue[5]         2.0              1
# 3783              lidarRearLeft.eth[0]  queue[5]         2.0              1
# 3791             lidarRearRight.eth[0]  queue[5]         2.0              1
# 3831                       adas.eth[0]  queue[2]         1.0              1
# 3799                cameraFront.eth[0]  queue[5]         1.0              2
# 3807                 cameraRear.eth[0]  queue[5]         1.0              1
# 4415            switchRearRight.eth[3]  queue[0]         1.0              2
# 4431        connectivityGateway.eth[0]  queue[2]         1.0              1
# 4025            switchRearRight.eth[1]  queue[2]         1.0              2
#
#                                            times of max
# 3687                                              [0.0]
# 3695                                              [0.0]
# 3711                                              [0.0]
# 3759                                              [0.0]
# 3743                                              [0.0]
# 4383                                   [0.000128456945]
# 4224                     [9.8625999e-05, 9.9297999e-05]
# 3703                                              [0.0]
# 3940                                   [8.999945475021]
# 3971                   [9.999955775617, 9.999956447615]
# 3719                                              [0.0]
# 3916   [2.000037908459, 2.000038580459, 2.000039252459]
# 3900                                   [9.999945480447]
# 4048                                      [3.50425e-05]
# 3815                                              [0.0]
# 4017                                      [5.21545e-05]
# 4009                                   [2.999985906689]
# 3963                                  [11.999895629271]
# 4033  [4.999960616578, 4.999961288578, 4.99996167744...
# 3751                                              [0.0]
# 4359                                       [9.2666e-05]
# 4271                                     [0.0316657465]
# 4407                                       [6.6186e-05]
# 4095                    [3.99997245844, 7.999931558018]
# 4079  [4.999963551475, 4.999964319475, 4.99996508747...
# 4071  [1.000009911216, 1.000010599216, 1.99999373533...
# 4125                   [4.999963661985, 7.999934373922]
# 4193     [3.99997245844, 7.999930950119, 7.99993154212]
# 4170                   [4.999963661985, 7.999934373922]
# 4185                                    [3.99997245844]
# 3387                                   [2.999981988604]
# 3627                    [1.99998291544, 9.999904814548]
# 3417                   [7.999926519659, 9.999906994449]
# 4391  [6.25945e-05, 6.32665e-05, 6.39385e-05, 6.4610...
# 3462   [3.999965074128, 4.999954895475, 6.999935802304]
# 4375                         [3.87145e-05, 3.93865e-05]
# 3507                              [1.0, 1.999982915538]
# 3552                   [2.999973152828, 5.999943096854]
# 3567  [2.999973152928, 5.999943864996, 8.99991457715...
# 3582  [2.999973152784, 5.999943864977, 8.99991457715...
# 3597  [2.999973152792, 5.999943864974, 8.99991457716...
# 3612              [1.0, 3.999963390188, 9.999904814549]
# 4455                                      [9.31465e-05]
# 3642                                   [4.999952939443]
# 4140                                   [1.000009442421]
# 3657                                              [0.0]
# 3767             [0.0, 8.999912136552, 11.999882848772]
# 3775                                              [0.0]
# 3783                                              [0.0]
# 3791                                              [0.0]
# 3831                                              [0.0]
# 3799                               [0.0, 6.99993424454]
# 3807                                              [0.0]
# 4415                   [1.162021286338, 4.536987375005]
# 4431                                   [0.000224113461]
# 4025                      [3.5945e-06, 10.914927252308]

# %%
prio6_qvs = qvs[['device+port', 'queue', 'max length', 'number of max', 'times of max']].loc[qvs['module'] == "Car.switchRearLeft.eth[4].macLayer.queue.queue[6]"]
for t in prio6_qvs['times of max']:
    print (t)
# Out:
# [3.38420000e-05 9.58420000e-05 1.03384200e-03 ... 1.19989787e+01
#  1.19999167e+01 1.19999787e+01]

# %% [markdown]
# #### plot largest 5 queues per prio

# %%
plts_queues = []
for prio, g in qvs.groupby('queue'):
    plts_queues.append(g.sort_values('max length', ascending=False).head(5))

df_plt_q = pd.concat(plts_queues)

# %%
for idx, row in df_plt_q.loc[df_plt_q['queue'] == "queue[7]"].iterrows():
    plt.plot(row['vectime'], row['vecvalue'], label=row['module'])
    plt.title("Queue sizes for Priority 7 ")
    plt.xlabel("Time [s]")
    plt.ylabel("Queue size [num packets]")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
for idx, row in df_plt_q.loc[df_plt_q['queue'] == "queue[6]"].iterrows():
    plt.plot(row['vectime'], row['vecvalue'], label=row['module'])
    plt.title("Queue sizes for Priority 6 ")
    plt.xlabel("Time [s]")
    plt.ylabel("Queue size [num packets]")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
for idx, row in df_plt_q.loc[df_plt_q['queue'] == "queue[5]"].iterrows():
    plt.plot(row['vectime'], row['vecvalue'], label=row['module'])
    plt.title("Queue sizes for Priority 5 ")
    plt.xlabel("Time [s]")
    plt.ylabel("Queue size [num packets]")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
for idx, row in df_plt_q.loc[df_plt_q['queue'] == "queue[4]"].iterrows():
    plt.plot(row['vectime'], row['vecvalue'], label=row['module'])
    plt.title("Queue sizes for Priority 4 ")
    plt.xlabel("Time [s]")
    plt.ylabel("Queue size [num packets]")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
for idx, row in df_plt_q.loc[df_plt_q['queue'] == "queue[2]"].iterrows():
    plt.plot(row['vectime'], row['vecvalue'], label=row['module'])
    plt.title("Queue sizes for Priority 2 ")
    plt.xlabel("Time [s]")
    plt.ylabel("Queue size [num packets]")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
for idx, row in df_plt_q.loc[df_plt_q['queue'] == "queue[0]"].iterrows():
    plt.plot(row['vectime'], row['vecvalue'], label=row['module'])
    plt.title("Queue sizes for Priority 0 ")
    plt.xlabel("Time [s]")
    plt.ylabel("Queue size [num packets]")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# ## Eval for szenario

# %% [markdown]
# ### latencies over time

# %%
for idx, row in l_p6.iterrows():
    plt.plot(row['vectime'], row['vecvalue'], label=row['module'])
    plt.title("Latency of Prio 6 streams")
    plt.xlabel("Time [s]")
    plt.ylabel("Latency [s]")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
for idx, row in l_p5.iterrows():
    plt.plot(row['vectime'], row['vecvalue'], label=row['module'])
    plt.title("Latency of Prio 5 streams")
    plt.xlabel("Time [s]")
    plt.ylabel("Latency [s]")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# ## Num packets

# %%
def sourceorsink(attrname):
    if "localPort" in attrname:
        return "sink"
    elif "destPort" in attrname:
        return "source"
    elif "connectPort" in attrname: # this is TCP client
        return "source" 

def appports(df):
    r = df[['attrname', 'attrvalue']].dropna()
    info = r.loc[r['attrname'].str.contains("localPort|destPort|connectPort")].copy()
    #d = df.loc[df['attrname'].str.contains("destPort"), ['attrname', 'attrvalue']].copy()
    #c = df.loc[df['attrname'].str.contains("connectPort"), ['attrname', 'attrvalue']].copy()
    #info = pd.concat([l,d])
    info['deviceapp'] = info.apply(lambda row: get_devicePort(row['attrname']), axis=1)
    info['sourcesink'] = info.apply(lambda row: sourceorsink(row['attrname']), axis=1)
    info['port'] = info['attrvalue']
    
    return dict(zip(info.deviceapp, info.port))

def extract_numpacks(df):
    res = df[['runID', 'module', 'value']].dropna()
    res['device'] = res.apply(lambda row: get_device(row['module']), axis=1)
    res['device+app'] = res.apply(lambda row: get_devicePort(row['module']), axis=1)
    res['streamname'] = res.apply(lambda row: get_streamId(row['module'], df), axis=1)
    # get the application port (local and/or destination) to match apps later
    app_ports = appports(df)
    res['app-port'] = res.apply(lambda row: app_ports[row['device+app']], axis=1)
    return res

# %%
res_sources = results.read_result_files(filenames = config_sca,
                                 filter_expression = "module=~ *.io AND name =~ packetSent:count")
res_sinks = results.read_result_files(filenames = config_sca,
                                 filter_expression = "module =~ *.io AND name =~ packetReceived:count")

d_sources = extract_numpacks(res_sources)
d_sources['srcsink'] = "source"
d_sinks = extract_numpacks(res_sinks)
d_sinks['srcsink'] = "sink"

by_sink = []
for appport, group in d_sinks.groupby('app-port'):
    src = d_sources.loc[d_sources['app-port'] == appport]
    srcapp = src['device+app'].to_list()[0]
    srcpcks = src['value'].to_list()[0]
    for idx, row in group.iterrows():
        by_sink.append({ "app-port": appport,
                        "stream name": row['streamname'],
                        "source app": srcapp,
                        "destination app": row['device+app'],
                        "packets sent [count]": srcpcks,
                        "packets received [count]": row['value'],
                        "packets difference": srcpcks - row['value']})

packet_diff = pd.DataFrame(by_sink)

# %%
packet_diff.sort_values('packets difference', ascending = True)
# Out:
#     app-port      stream name                        source app  \
# 4       1100     SManualBrake   zonalControllerFrontLeft.app[1]
# 9       1200     SManualSteer   zonalControllerFrontLeft.app[2]
# 5       1100     SManualBrake   zonalControllerFrontLeft.app[1]
# 2       1000  SManualThrottle   zonalControllerFrontLeft.app[0]
# 10      1200     SManualSteer   zonalControllerFrontLeft.app[2]
# ..       ...              ...                               ...
# 30      3001          SACC_06   zonalControllerFrontLeft.app[7]
# 115     3040      STSG_HFS_01  zonalControllerFrontLeft.app[46]
# 52      3013      SGateway_78  zonalControllerFrontLeft.app[19]
# 111     3038       STSG_FT_01  zonalControllerFrontLeft.app[44]
# 70      3019     SKN_Rearview  zonalControllerFrontLeft.app[25]
#
#                        destination app  packets sent [count]  \
# 4       zonalControllerRearLeft.app[1]               12001.0
# 9       zonalControllerRearLeft.app[2]               12001.0
# 5      zonalControllerRearRight.app[1]               12001.0
# 2      zonalControllerRearRight.app[0]               12001.0
# 10     zonalControllerRearRight.app[2]               12001.0
# ..                                 ...                   ...
# 30    zonalControllerRearRight.app[85]                 601.0
# 115  zonalControllerRearRight.app[179]                 121.0
# 52   zonalControllerRearRight.app[110]                 121.0
# 111  zonalControllerRearRight.app[176]                 121.0
# 70   zonalControllerRearRight.app[124]                  25.0
#
#      packets received [count]  packets difference
# 4                     21574.0             -9573.0
# 9                     21573.0             -9572.0
# 5                     21565.0             -9564.0
# 2                     21564.0             -9563.0
# 10                    21564.0             -9563.0
# ..                        ...                 ...
# 30                      600.0                 1.0
# 115                     120.0                 1.0
# 52                      120.0                 1.0
# 111                     120.0                 1.0
# 70                       24.0                 1.0
#
# [468 rows x 7 columns]

# %%
packet_diff.to_csv(pre+"num_packets.csv", index=False)
